# %% [markdown]
# ## Deadline
#
# Wednesday, November 22, 2017, 11:59PM
#
# ## Important notes
#
# - When you push your Notebook to GitHub, all the cells must already have been evaluated.
# - Don't forget to add a textual description of your thought process and of any assumptions you've made.
# - Please write all your comments in English, and use meaningful variable names in your code.
#
# ## Question 1: Propensity score matching
#
# In this exercise, you will apply [propensity score matching](http://www.stewartschultz.com/statistics/books/Design%20of%20observational%20studies.pdf), which we discussed in lecture 5 ("Observational studies"), in order to draw conclusions from an observational study.
#
# We will work with a by-now classic dataset from Robert LaLonde's study "[Evaluating the Econometric Evaluations of Training Programs](http://people.hbs.edu/nashraf/LaLonde_1986.pdf)" (1986).
# The study investigated the effect of a job training program ("National Supported Work Demonstration") on the real earnings of an individual, a couple of years after completion of the program.
# Your task is to determine the effectiveness of the "treatment" represented by the job training program.
#
# #### Dataset description
#
# - `treat`: 1 if the subject participated in the job training program, 0 otherwise
# - `age`: the subject's age
# - `educ`: years of education
# - `race`: categorical variable with three possible values: Black, Hispanic, or White
# - `married`: 1 if the subject was married at the time of the training program, 0 otherwise
# - `nodegree`: 1 if the subject has earned no school degree, 0 otherwise
# - `re74`: real earnings in 1974 (pre-treatment)
# - `re75`: real earnings in 1975 (pre-treatment)
# - `re78`: real earnings in 1978 (outcome)
#
# If you want to brush up your knowledge on propensity scores and observational studies, we highly recommend Rosenbaum's excellent book on the ["Design of Observational Studies"](http://www.stewartschultz.com/statistics/books/Design%20of%20observational%20studies.pdf). Even just reading the first chapter (18 pages) will help you a lot.
#
# #### 1. A naive analysis
#
# Compare the distribution of the outcome variable (`re78`) between the two groups, using plots and numbers.
# To summarize and compare the distributions, you may use the techniques we discussed in lectures 4 ("Read the stats carefully") and 6 ("Data visualization").
#
# What might a naive "researcher" conclude from this superficial analysis?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.preprocessing import OneHotEncoder
from pandas.tools.plotting import scatter_matrix
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_val_score
import seaborn as sns
# %matplotlib inline

# %%
file = 'lalonde.csv'

# %%
lalonde = pd.read_csv(file, )

# %%
sns.barplot(x='treat', y='re78', data=lalonde)

# %% [markdown]
# #### 2. A closer look at the data
#
# You're not naive, of course (and even if you are, you've learned certain things in ADA), so you aren't content with a superficial analysis such as the above.
# You're aware of the dangers of observational studies, so you take a closer look at the data before jumping to conclusions.
#
# For each feature in the dataset, compare its distribution in the treated group with its distribution in the control group, using plots and numbers.
# As above, you may use the techniques we discussed in class for summarizing and comparing the distributions.
#
# What do you observe?
# Describe what your observations mean for the conclusions drawn by the naive "researcher" from his superficial analysis.

# %%
sns.boxplot(x='treat', y='re78', data=lalonde)

# %%
sns.stripplot(x='treat', y='re78', data=lalonde)

# %% [markdown]
# #### 3. A propsensity score model
#
# Use logistic regression to estimate propensity scores for all points in the dataset.
# You may use `sklearn` to fit the logistic regression model and apply it to each data point to obtain propensity scores:
#
# ```python
# from sklearn import linear_model
# logistic = linear_model.LogisticRegression()
# ```
#
# Recall that the propensity score of a data point represents its probability of receiving the treatment, based on its pre-treatment features (in this case, age, education, pre-treatment income, etc.).
# To brush up on propensity scores, you may read chapter 3.3 of the above-cited book by Rosenbaum or [this article](https://drive.google.com/file/d/0B4jctQY-uqhzTlpBaTBJRTJFVFE/view).
#
# Note: you do not need a train/test split here. Train and apply the model on the entire dataset. If you're wondering why this is the right thing to do in this situation, recall that the propensity score model is not used in order to make predictions about unseen data. Its sole purpose is to balance the dataset across treatment groups.
# (See p. 74 of Rosenbaum's book for an explanation why slight overfitting is even good for propensity scores.
# If you want even more information, read [this article](https://drive.google.com/file/d/0B4jctQY-uqhzTlpBaTBJRTJFVFE/view).)

# %%
print(lalonde.head())
# Out:
#      id  treat  age  educ  black  hispan  married  nodegree  re74  re75  \
# 0  NSW1      1   37    11      1       0        1         1   0.0   0.0
# 1  NSW2      1   22     9      0       1        0         1   0.0   0.0
# 2  NSW3      1   30    12      1       0        0         0   0.0   0.0
# 3  NSW4      1   27    11      1       0        0         1   0.0   0.0
# 4  NSW5      1   33     8      1       0        0         1   0.0   0.0
#
#          re78
# 0   9930.0460
# 1   3595.8940
# 2  24909.4500
# 3   7506.1460
# 4    289.7899

# %%
from sklearn.preprocessing import normalize
x = lalonde.drop(['id', 're78'], axis=1)
logistic = LogisticRegression()
logistic.fit(X=x, y=lalonde['treat'])
propensity = logistic.predict_proba(x)
print(propensity)
# Out:
# [[ 0.12210616  0.87789384]
#  [ 0.14815303  0.85184697]
#  [ 0.04387151  0.95612849]
#  ...,
#  [ 0.99064868  0.00935132]
#  [ 0.88450024  0.11549976]
#  [ 0.96555324  0.03444676]]

# %%
len(propensity)
# Out:
# 614

# %% [markdown]
# #### 4. Balancing the dataset via matching
#
# Use the propensity scores to match each data point from the treated group with exactly one data point from the control group, while ensuring that each data point from the control group is matched with at most one data point from the treated group.
# (Hint: you may explore the `networkx` package in Python for predefined matching functions.)
#
# Your matching should maximize the similarity between matched subjects, as captured by their propensity scores.
# In other words, the sum (over all matched pairs) of absolute propensity-score differences between the two matched subjects should be minimized.
#
# After matching, you have as many treated as you have control subjects.
# Compare the outcomes (`re78`) between the two groups (treated and control).
#
# Also, compare again the feature-value distributions between the two groups, as you've done in part 2 above, but now only for the matched subjects.
# What do you observe?
# Are you closer to being able to draw valid conclusions now than you were before?
#
# ---
#
# We use a node attribute named “bipartite” with values 0 or 1 to identify the sets each node belongs to.

# %%
import networkx as nx

# %%
# Graph initialization
B = nx.Graph()

# Split the ids between treated and non treated
treated = lalonde.loc[lalonde['treat'] == 1].id
not_treated = lalonde.loc[lalonde['treat'] == 0].id

# Add the two sets of ids in the bipartite graph
B.add_nodes_from(treated, bipartite = 1)
B.add_nodes_from(not_treated, bipartite = 0)

# Split the propensity scores between treated and not treated
score_treated = propensity[np.where(lalonde['treat'] == 1)[0]]
score_nontreated = propensity[np.where(lalonde['treat'] == 0)[0]]


for i, st in enumerate(score_treated):
    for j, sn in enumerate(score_nontreated):
        B.add_edge(treated.iloc[i], not_treated.iloc[j], weight = np.abs(st - sn))
        

matching = nx.bipartite.maximum_matching(B)
print(len(matching))
# Out:
# 370

# %%
print(matching)
# Out:
# {'NSW45': 'PSID198', 'NSW177': 'PSID272', 'PSID198': 'NSW45', 'PSID121': 'NSW151', 'NSW24': 'PSID111', 'PSID200': 'NSW28', 'PSID111': 'NSW24', 'PSID47': 'NSW152', 'NSW167': 'PSID284', 'PSID209': 'NSW68', 'NSW144': 'PSID64', 'NSW63': 'PSID137', 'NSW163': 'PSID274', 'PSID271': 'NSW149', 'NSW17': 'PSID286', 'NSW151': 'PSID121', 'PSID9': 'NSW5', 'NSW16': 'PSID402', 'NSW134': 'PSID51', 'PSID284': 'NSW167', 'PSID202': 'NSW137', 'PSID299': 'NSW54', 'PSID161': 'NSW72', 'NSW50': 'PSID127', 'NSW115': 'PSID43', 'NSW85': 'PSID165', 'PSID64': 'NSW144', 'NSW183': 'PSID287', 'NSW117': 'PSID318', 'PSID101': 'NSW106', 'PSID306': 'NSW52', 'PSID286': 'NSW17', 'PSID272': 'NSW177', 'PSID71': 'NSW4', 'PSID402': 'NSW16', 'NSW93': 'PSID114', 'NSW60': 'PSID363', 'PSID93': 'NSW69', 'NSW66': 'PSID169', 'NSW101': 'PSID408', 'PSID292': 'NSW61', 'NSW94': 'PSID343', 'NSW89': 'PSID264', 'PSID281': 'NSW65', 'PSID397': 'NSW78', 'NSW131': 'PSID150', 'NSW162': 'PSID214', 'PSID43': 'NSW115', 'PSID134': 'NSW34', 'PSID165': 'NSW85', 'PSID287': 'NSW183', 'PSID182': 'NSW41', 'PSID318': 'NSW117', 'NSW178': 'PSID249', 'NSW33': 'PSID240', 'PSID380': 'NSW184', 'NSW14': 'PSID31', 'NSW143': 'PSID205', 'NSW127': 'PSID280', 'PSID304': 'NSW128', 'PSID248': 'NSW155', 'PSID88': 'NSW15', 'NSW130': 'PSID212', 'PSID361': 'NSW108', 'NSW123': 'PSID35', 'NSW102': 'PSID359', 'PSID180': 'NSW122', 'PSID259': 'NSW121', 'NSW137': 'PSID202', 'NSW132': 'PSID61', 'PSID114': 'NSW93', 'NSW29': 'PSID195', 'NSW97': 'PSID256', 'NSW113': 'PSID20', 'PSID53': 'NSW109', 'NSW135': 'PSID107', 'PSID252': 'NSW80', 'NSW10': 'PSID16', 'PSID408': 'NSW101', 'PSID363': 'NSW60', 'NSW166': 'PSID22', 'NSW157': 'PSID56', 'NSW154': 'PSID199', 'NSW73': 'PSID27', 'PSID263': 'NSW87', 'NSW148': 'PSID295', 'NSW125': 'PSID239', 'NSW18': 'PSID10', 'NSW110': 'PSID186', 'PSID169': 'NSW66', 'NSW180': 'PSID265', 'PSID264': 'NSW89', 'PSID150': 'NSW131', 'NSW11': 'PSID98', 'PSID223': 'NSW168', 'PSID5': 'NSW114', 'PSID424': 'NSW129', 'PSID55': 'NSW142', 'NSW88': 'PSID338', 'NSW160': 'PSID337', 'NSW12': 'PSID1', 'PSID83': 'NSW146', 'PSID22': 'NSW166', 'PSID366': 'NSW153', 'NSW147': 'PSID190', 'NSW81': 'PSID215', 'PSID205': 'NSW143', 'NSW25': 'PSID383', 'NSW161': 'PSID109', 'NSW145': 'PSID314', 'PSID113': 'NSW30', 'PSID325': 'NSW159', 'PSID195': 'NSW29', 'PSID258': 'NSW105', 'NSW46': 'PSID206', 'PSID176': 'NSW56', 'NSW69': 'PSID93', 'NSW6': 'PSID208', 'NSW36': 'PSID220', 'PSID343': 'NSW94', 'PSID120': 'NSW96', 'PSID339': 'NSW38', 'PSID61': 'NSW132', 'NSW57': 'PSID346', 'PSID364': 'NSW169', 'NSW119': 'PSID210', 'NSW7': 'PSID29', 'PSID212': 'NSW130', 'PSID256': 'NSW97', 'NSW179': 'PSID327', 'PSID185': 'NSW172', 'PSID399': 'NSW32', 'PSID282': 'NSW181', 'PSID11': 'NSW9', 'PSID16': 'NSW10', 'PSID347': 'NSW83', 'NSW118': 'PSID105', 'NSW40': 'PSID313', 'PSID345': 'NSW8', 'PSID56': 'NSW157', 'NSW92': 'PSID367', 'PSID34': 'NSW35', 'NSW124': 'PSID50', 'PSID62': 'NSW1', 'NSW55': 'PSID100', 'PSID199': 'NSW154', 'PSID27': 'NSW73', 'PSID222': 'NSW3', 'PSID295': 'NSW148', 'NSW3': 'PSID222', 'PSID274': 'NSW163', 'NSW23': 'PSID422', 'NSW84': 'PSID117', 'PSID261': 'NSW64', 'NSW159': 'PSID325', 'PSID239': 'NSW125', 'PSID149': 'NSW37', 'PSID86': 'NSW185', 'NSW75': 'PSID426', 'PSID137': 'NSW63', 'NSW5': 'PSID9', 'NSW141': 'PSID166', 'PSID265': 'NSW180', 'NSW47': 'PSID158', 'NSW173': 'PSID139', 'NSW74': 'PSID156', 'PSID98': 'NSW11', 'PSID365': 'NSW21', 'NSW70': 'PSID151', 'NSW43': 'PSID21', 'NSW155': 'PSID248', 'NSW171': 'PSID77', 'PSID297': 'NSW13', 'NSW122': 'PSID180', 'PSID337': 'NSW160', 'NSW27': 'PSID204', 'NSW126': 'PSID122', 'NSW1': 'PSID62', 'PSID333': 'NSW112', 'PSID1': 'NSW12', 'PSID331': 'NSW136', 'NSW44': 'PSID371', 'NSW86': 'PSID72', 'PSID190': 'NSW147', 'PSID152': 'NSW42', 'PSID268': 'NSW76', 'NSW175': 'PSID410', 'PSID77': 'NSW171', 'NSW59': 'PSID429', 'PSID329': 'NSW19', 'PSID214': 'NSW162', 'PSID186': 'NSW110', 'PSID170': 'NSW39', 'PSID383': 'NSW25', 'NSW28': 'PSID200', 'PSID109': 'NSW161', 'NSW152': 'PSID47', 'NSW68': 'PSID209', 'PSID ...

# %%
matched_left = matching.keys()
matched_right = matching.values()
reduced_lalonde = lalonde.set_index('id')
reduced_ids = np.concatenate((np.array(list(matched_left)), np.array(list(matched_right))), axis=0)
reduced_lalonde.head()
reduced_lalonde = reduced_lalonde.loc[list(set(reduced_ids))]

# %%
sns.barplot(x='treat', y='re78', data=reduced_lalonde)

# %%
print(list(set(reduced_ids)))
# Out:
# ['NSW45', 'NSW177', 'PSID198', 'PSID121', 'NSW98', 'PSID200', 'PSID111', 'PSID47', 'NSW167', 'PSID209', 'NSW144', 'PSID271', 'NSW17', 'PSID9', 'NSW16', 'PSID284', 'NSW14', 'PSID299', 'PSID185', 'PSID161', 'NSW50', 'NSW115', 'NSW84', 'PSID64', 'NSW183', 'PSID137', 'PSID101', 'PSID306', 'PSID286', 'PSID272', 'PSID71', 'PSID402', 'NSW93', 'PSID93', 'NSW101', 'PSID292', 'PSID281', 'PSID397', 'PSID113', 'NSW162', 'PSID127', 'PSID43', 'PSID165', 'PSID287', 'PSID182', 'PSID318', 'NSW33', 'PSID380', 'NSW143', 'PSID304', 'NSW165', 'PSID88', 'PSID361', 'PSID180', 'PSID259', 'PSID134', 'NSW132', 'PSID114', 'NSW130', 'NSW97', 'PSID53', 'NSW135', 'PSID252', 'PSID408', 'PSID169', 'PSID363', 'NSW166', 'PSID263', 'NSW148', 'NSW18', 'NSW180', 'PSID264', 'PSID150', 'NSW11', 'PSID223', 'PSID214', 'PSID5', 'PSID55', 'NSW160', 'NSW12', 'PSID83', 'PSID366', 'PSID279', 'PSID240', 'PSID31', 'PSID205', 'NSW25', 'PSID280', 'NSW145', 'PSID328', 'PSID195', 'PSID258', 'NSW46', 'PSID176', 'PSID35', 'NSW36', 'PSID343', 'PSID359', 'PSID120', 'PSID61', 'NSW7', 'PSID202', 'PSID212', 'PSID256', 'NSW179', 'PSID62', 'PSID107', 'PSID399', 'PSID282', 'PSID11', 'PSID16', 'PSID347', 'PSID424', 'NSW40', 'PSID345', 'PSID22', 'PSID56', 'NSW124', 'NSW170', 'NSW55', 'NSW119', 'PSID199', 'PSID27', 'PSID222', 'PSID295', 'PSID274', 'NSW23', 'PSID261', 'PSID339', 'PSID239', 'PSID149', 'NSW75', 'PSID186', 'NSW141', 'PSID265', 'NSW47', 'NSW173', 'NSW74', 'PSID98', 'NSW138', 'PSID365', 'PSID297', 'PSID337', 'PSID338', 'PSID333', 'PSID1', 'NSW42', 'PSID331', 'NSW44', 'NSW86', 'PSID190', 'PSID152', 'PSID268', 'PSID329', 'PSID170', 'NSW151', 'PSID383', 'PSID109', 'NSW152', 'PSID314', 'NSW149', 'PSID73', 'PSID51', 'PSID414', 'PSID206', 'NSW106', 'PSID215', 'PSID208', 'PSID220', 'PSID381', 'PSID346', 'NSW184', 'NSW15', 'NSW121', 'PSID413', 'NSW53', 'NSW34', 'PSID39', 'PSID143', 'PSID102', 'PSID384', 'NSW155', 'NSW109', 'PSID46', 'PSID29', 'PSID310', 'PSID26', 'NSW87', 'NSW103', 'PSID327', 'NSW114', 'NSW142', 'PSID174', 'NSW146', 'PSID354', 'PSID232', 'NSW153', 'PSID249', 'PSID301', 'PSID224', 'PSID211', 'PSID105', 'PSID351', 'PSID312', 'PSID313', 'PSID367', 'NSW96', 'NSW32', 'NSW181', 'NSW9', 'PSID50', 'NSW83', 'PSID100', 'NSW8', 'PSID60', 'PSID210', 'PSID34', 'PSID334', 'NSW3', 'PSID257', 'NSW64', 'PSID96', 'PSID117', 'NSW21', 'PSID21', 'PSID94', 'PSID325', 'PSID376', 'PSID68', 'NSW136', 'NSW76', 'PSID425', 'NSW19', 'NSW39', 'PSID106', 'NSW156', 'PSID422', 'PSID166', 'PSID158', 'NSW48', 'PSID139', 'PSID156', 'PSID30', 'NSW150', 'PSID407', 'PSID151', 'PSID173', 'PSID300', 'PSID289', 'PSID248', 'NSW120', 'PSID77', 'PSID10', 'PSID335', 'PSID204', 'NSW2', 'NSW77', 'PSID122', 'PSID20', 'PSID2', 'PSID364', 'PSID371', 'PSID86', 'PSID72', 'PSID290', 'NSW174', 'NSW158', 'PSID6', 'NSW52', 'PSID410', 'PSID128', 'NSW128', 'NSW122', 'PSID429', 'PSID235', 'NSW62', 'PSID426', 'NSW26', 'NSW24', 'NSW63', 'NSW163', 'NSW31', 'NSW85', 'NSW117', 'NSW66', 'NSW60', 'NSW94', 'NSW56', 'NSW89', 'NSW131', 'NSW82', 'NSW58', 'NSW178', 'NSW127', 'NSW102', 'NSW137', 'NSW29', 'NSW113', 'NSW1', 'NSW10', 'NSW157', 'NSW154', 'NSW73', 'NSW125', 'NSW110', 'NSW65', 'NSW88', 'NSW147', 'NSW161', 'NSW6', 'NSW175', 'NSW57', 'NSW134', 'NSW118', 'NSW92', 'NSW159', 'NSW5', 'NSW172', 'NSW70', 'NSW171', 'NSW27', 'NSW126', 'NSW59', 'NSW28', 'NSW68', 'NSW123', 'NSW54', 'NSW72', 'NSW69', 'NSW61', 'NSW30', 'NSW41', 'NSW108', 'NSW91', 'NSW78', 'NSW176', 'NSW80', 'NSW168', 'NSW20', 'NSW105', 'NSW4', 'NSW81', 'NSW129', 'NSW38', 'NSW37', 'NSW13', 'NSW112', 'NSW67', 'NSW182', 'NSW49', 'NSW116', 'NSW90', 'NSW164', 'NSW139', 'NSW71', 'NSW95', 'NSW35', 'NSW43', 'NSW51', 'NSW79', 'NSW100', 'NSW133', 'NSW99', 'NSW104', 'NSW107', 'NSW140', 'NSW169', 'NSW185', 'NSW111', 'NSW22']

# %% [markdown]
# #### 5. Balancing the groups further
#
# Based on your comparison of feature-value distributions from part 4, are you fully satisfied with your matching?
# Would you say your dataset is sufficiently balanced?
# If not, in what ways could the "balanced" dataset you have obtained still not allow you to draw valid conclusions?
#
# Improve your matching by explicitly making sure that you match only subjects that have the same value for the problematic feature.
# Argue with numbers and plots that the two groups (treated and control) are now better balanced than after part 4.

# %% [markdown]
# #### 6. A less naive analysis
#
# Compare the outcomes (`re78`) between treated and control subjects, as you've done in part 1, but now only for the matched dataset you've obtained from part 5.
# What do you conclude about the effectiveness of the job training program?

# %% [markdown]
# ## Question 2: Applied ML
#
# We are going to build a classifier of news to directly assign them to 20 news categories. Note that the pipeline that you will build in this exercise could be of great help during your project if you plan to work with text!
#
# #### Part 1
# Load the 20newsgroup dataset. It is, again, a classic dataset that can directly be loaded using sklearn ([link](http://scikit-learn.org/stable/datasets/twenty_newsgroups.html)).
# [TF-IDF](https://en.wikipedia.org/wiki/Tf%E2%80%93idf), short for term frequency–inverse document frequency, is of great help when if comes to compute textual features. Indeed, it gives more importance to terms that are more specific to the considered articles (TF) but reduces the importance of terms that are very frequent in the entire corpus (IDF). Compute TF-IDF features for every article using [TfidfVectorizer](http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html). Then, split your dataset into a training, a testing and a validation set (10% for validation and 10% for testing). Each observation should be paired with its corresponding label (the article category).

# %% [markdown]
# #### Part 2
#
# Train a random forest on your training set. Try to fine-tune the parameters of your predictor on your validation set using a simple grid search on the number of estimator "n_estimators" and the max depth of the trees "max_depth". Then, display a confusion matrix of your classification pipeline. Lastly, once you assessed your model, inspect the `feature_importances_` attribute of your random forest and discuss the obtained results.
