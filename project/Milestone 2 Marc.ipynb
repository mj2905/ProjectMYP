# %% [markdown]
# # Books versus eBooks : The customer's choice

# %% [markdown]
# You need to have the metadata.json and the two 5-core files reviews_Books_5.json and reviews_Kindle_Store_5.json at the same level as the notebook.
#
# For the questions asked for Milestone 2, please refer to the README file, where you will see a part dedicated to milestone 2. In this Notebook, we don't answer specifically to these questions, but we speak at each step what we technically made and failed.

# %% [markdown]
# ## Data retrieval

# %%
import pandas as pd
import re
import numpy as np
import requests
import time
from bs4 import BeautifulSoup
from ast import literal_eval

# %% [markdown]
# #### Warning :
# There are several booleans in this cell. They are useful to indicate if we need to perform some key data filtering and transformation in the whole notebook. The first one is set to True as it creates a file that is bigger than 300Mo, so that we can't put it in github. You will have to compute it if you run the notebook (it takes some time). The other files are on github, so all other booleans are set to False.

# %%
metadata_path = 'metadata.json'
books_metadata_path = 'books_metadata_with_bracket.csv'
ebooks_metadata_title_path = 'ebooks_metadata_title.csv'
ebooks_asin = 'ebooks_asin.csv'
books_5core_path = 'reviews_Books_5.json'
kindle_5core_path = 'reviews_Kindle_Store_5.json'
amazon_ebooks = 'ebooks_title_from_amazon_complete.csv'
amazon_aws_ebooks = 'ebooks_metadata_amazon.csv'
amazon_aws_ebooks_undefined = 'ebooks_metadata_amazon_undefined.csv'
amazon_aws_ebooks_log = 'ebooks_metadata_amazon_log.csv'
asindb_ebooks = 'ebooks_title_from_asindb.csv'

amazon_aws_books_yves = 'books_metadata_amazon_yves.csv'
amazon_aws_books_pa = 'books_metadata_amazon_pa.csv'

matched_books_path = 'matched_books.csv'
matched_ebooks_path = 'matched_ebooks.csv'
weighted_scores_books_path = 'weighted_scores_books.csv'
weighted_scores_ebooks_path = 'weighted_scores_ebooks.csv'


WRITE_BOOKS_METADATA = False
WRITE_EBOOKS_METADATA_TITLE = False
WRITE_EBOOK_ASIN = False
AMAZON_GET_TITLE = False
ASINDB_GET_TITLE = False
WRITE_FIND_MATCHED = False
WRITE_WEIGHTED_SCORE = True

# %% [markdown]
# As for our project, we need to obtain ebook data and book data, we chose the Amazon dataset. On this <a href='http://jmcauley.ucsd.edu/data/amazon/'>link</a>, we have downloaded the Books and Kindle Store 5-core files. However, those files contain reviews, so that we have no information about the article title or price.
# For that reason, we had to use the metadata file, acting as an intermediate table (relationship).
#
# We obtained the metadata.json file from the cluster, as it was not available in the website.
# We accessed the cluster using ssh@iccluster060.iccluster.epfl.ch, then using
# ```shell
# hadoop fs -get /datasets/productGraph/metadata.json /buffer
# ```
# to move the dataset to a folder we could connect to with SCP to download it on our computer.

# %% [markdown]
# It's a json file, that is not readable using the pandas read_json method. We had to use the Code part from <a href='http://jmcauley.ucsd.edu/data/amazon/'>here</a> to read it. We can see a way to read the file (a limited portion of it) below :

# %%
def read_json(path, limit = 2): 
    g = open(path, 'r') 
    df = {}
    for i, l in enumerate(g): 
        if i < limit:
            df[i] = eval(l)
        else:
            break
    return pd.DataFrame.from_dict(df, orient='index')

def read_csv(path, limit = 2): 
    return pd.read_csv(path, nrows=limit)
            
read_json(metadata_path)
# Out:
#          asin                salesRank  \
# 0  0001048791       {'Books': 6334800}
# 1  0000143561  {'Movies & TV': 376041}
#
#                                                imUrl               categories  \
# 0  http://ecx.images-amazon.com/images/I/51MKP0T4...                [[Books]]
# 1  http://g-ecx.images-amazon.com/images/G/01/x-s...  [[Movies & TV, Movies]]
#
#                                                title  \
# 0  The Crucible: Performed by Stuart Pankin, Jero...
# 1  Everyday Italian (with Giada de Laurentiis), V...
#
#                                          description  price  \
# 0                                                NaN    NaN
# 1  3Pack DVD set - Italian Classics, Parties and ...  12.99
#
#                                              related
# 0                                                NaN
# 1  {'also_viewed': ['B0036FO6SI', 'B000KL8ODE', '...

# %% [markdown]
# However, this metadata.json file takes more than 10 Go, for 9430088 entries (obtained by doing a wc -l metadata.json), so it does not fit in memory. Thus, as we will do a lot of tests later, we wanted to create a subfile containing only the Books metadata (we don't need video games metadata for example), with a subset of columns. We also want to write it in the csv format, to manipulate it in an easier way later.
#
# We use the regex "\[\'books" in an ignore case mode, to obtain only entries that have a category tag beginning with [Books. In fact, if we want to use the regex 'book', some entries like 0078800242 or B00000078S are not books at all, even if there is Books in the title or the category tag. The '[' is useful here to avoir this behavior.

# %%
def read_book_metadata(path, regex): 
    g = open(path, 'r') 
    for l in g: 
        book = regex.search(l)
        if book:
            yield eval(l) 
            
def write_df_books_metadata(from_, to, regex, columns_to_keep): 
    i = 0 
    df = {} 
    for d in read_book_metadata(from_, regex): 
        df[i] = d 
        i += 1 
        if i % 10000 == 0: # Here, we choose to write everything every 10'000 book entries, and clear the dataframe to free memory.
            pd.DataFrame.from_dict(df, orient='index')[columns_to_keep].to_csv(to, header=False,mode='a')
            df = {}

COLUMNS_TO_KEEP = ['asin', 'salesRank', 'categories', 'title', 'price']
regex = re.compile('\[\'books', re.IGNORECASE)

if WRITE_BOOKS_METADATA:
    pd.DataFrame(columns=[COLUMNS_TO_KEEP]).to_csv(books_metadata_path)
    write_df_books_metadata(metadata_path, books_metadata_path, regex, COLUMNS_TO_KEEP)

# %% [markdown]
# And if we read what we just wrote :

# %%
read_csv(books_metadata_path)
# Out:
#    Unnamed: 0     asin            salesRank   categories  \
# 0           0  1048791   {'Books': 6334800}  [['Books']]
# 1           1  1048775  {'Books': 13243226}  [['Books']]
#
#                                                title  price
# 0  The Crucible: Performed by Stuart Pankin, Jero...    NaN
# 1     Measure for Measure: Complete &amp; Unabridged    NaN

# %% [markdown]
# We also wanted to obtain the ebooks titles, price etc..
# For the category filter, we have to use the same trick as for the Books one : "\[\'Kindle". Please note that some book metadatas above are in fact kindle store metadatas, because the category can contain both. However, it's not a big deal if we want to do the merge later, because as we will see, pretty much no ebook has a title in the given metadata.
#
# However, for the metadatas for ebooks, there was a problem at that step :

# %%
def read_ebook_metadata(path, regex): 
    g = open(path, 'r') 
    for l in g: 
        ebook = regex.search(l)
        if ebook:
            yield eval(l) 
def obtain_df_ebooks_metadata(from_, to, regex): 
    i = 0 
    df = {} 
    count = 0
    for d in read_ebook_metadata(from_, regex): 
        count += 1
        if(d.get('title')):
            df[i] = {'asin': d.get('asin'), 'title': d.get('title')}
            i += 1 
    pd.DataFrame.from_dict(df, orient='index').to_csv(to)
    print('Total ebooks in metadatas:', count)


regex = re.compile('\[\'Kindle', re.IGNORECASE)

if WRITE_EBOOKS_METADATA_TITLE:
    obtain_df_ebooks_metadata(metadata_path, ebooks_metadata_title_path, regex)

# %% [markdown]
# We see right below that 44 entries out of 434702 have a title. Of course, it's not good at all, since we want to merge books and ebooks using the title field.

# %%
read_csv(ebooks_metadata_title_path, None).shape[0]
# Out:
# 44

# %% [markdown]
# Thus, we need to obtain the title field from another source. The first idea was to retrieve this information from Amazon directly, as we wanted to do for the user location. For that, we need to have a list of the ebooks asin (Amazon Standard Identification Numbers). We obtain it from the Kindle Store 5-core file.

# %%
def read_ebook_5core(path, regex): 
    g = open(path, 'r') 
    for l in g: 
        yield eval(l) 
def write_ebook_asin(from_, to): 
    i = 0 
    df = {} 
    for d in read_ebook_5core(from_, regex): 
        df[i] = d 
        i += 1 
        if i % 10000 == 0:
            if i % 100000 == 0:
                print(i) #to show the progression
            pd.DataFrame.from_dict(df, orient='index')[['asin']].to_csv(to, header=False,mode='a')
            df = {}
    pd.DataFrame.from_dict(df, orient='index')[['asin']].to_csv(to, header=False,mode='a')
    df = {}

if WRITE_EBOOK_ASIN:
    pd.DataFrame(columns=[['asin']]).to_csv(ebooks_asin)
    write_ebook_asin(kindle_5core_path, ebooks_asin)

# %% [markdown]
# As we were using the Kindle Store 5-core file, there are asin duplicates. We thus make it unique when we read.

# %%
ebooks_asin_unique = pd.read_csv('ebooks_asin.csv',usecols=[1]).asin.unique()
ebooks_asin_unique
# Out:
# array(['B000F83SZQ', 'B000FA64PA', 'B000FA64PK', ..., 'B00M029T4O',
#        'B00M0RE7CS', 'B00M13FNSS'], dtype=object)

# %% [markdown]
# For every Amazon article with asin *xasinx*, the corresponding web page is https://www.amazon.com/dp/*xasinx*/ref=rdr_kindle_ext_tmb.

# %%
prefix = 'https://www.amazon.com/dp/'
suffix = '/ref=rdr_kindle_ext_tmb'

USER_AGENT_CHOICES = [
    'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:23.0) Gecko/20100101 Firefox/23.0',
    'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/29.0.1547.62 Safari/537.36',
    'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; WOW64; Trident/6.0)',
    'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/33.0.1750.146 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/33.0.1750.146 Safari/537.36',
    'Mozilla/5.0 (X11; Linux x86_64; rv:24.0) Gecko/20140205 Firefox/24.0 Iceweasel/24.3.0',
    'Mozilla/5.0 (Windows NT 6.2; WOW64; rv:28.0) Gecko/20100101 Firefox/28.0',
    'Mozilla/5.0 (Windows NT 6.2; WOW64; rv:28.0) AppleWebKit/534.57.2 (KHTML, like Gecko) Version/5.1.7 Safari/534.57.2',
]

# %% [markdown]
# We have to rotate the user-agent so that the bot is less likely to be considered as one. This is why we have a User-Agent array.
# At the beginning, this method was working quite well : we had obtained 503 tuples (title, category, page number, language) over 1000 requests, which could mean that we had solved the problem. However, when looking at the distribution of the 503 tuples, we could see that at the beginning, everything behaves well, we obtain most of the entries (the other ones being like the B000JMKU0Y one, an obsolete entry, that only has customer reviews).

# %%
if AMAZON_GET_TITLE:
    
    LIMIT = 10
    
    undefined = 0
    defined = 0
    dataframe_original = pd.DataFrame(columns=[['asin', 'title', 'Category', 'PageNum', 'Language']])
    dataframe = dataframe_original.copy()

    dataframe_original.to_csv(amazon_ebooks)

    for i, asin in enumerate(ebooks_asin_unique[:LIMIT]):

        if i%10==0:
            headers = {'User-Agent':USER_AGENT_CHOICES[np.random.randint(0, len(USER_AGENT_CHOICES))]}
            if i > 0:
                print('undefined:', undefined, '/ defined:', defined)
                dataframe.to_csv(amazon_ebooks, header=False,mode='a')
                dataframe = dataframe_original.copy()


        r = requests.get(prefix + asin + suffix, headers=headers)
        page_body = r.text
        soup = BeautifulSoup(page_body, 'html.parser')
        title = soup.find_all('span', id='ebooksProductTitle')
        if(len(title) == 0):
            undefined += 1
        else:
            defined += 1
            title = title[0].text

            ul = soup.find_all('ul', class_='a-unordered-list a-horizontal a-size-small')
            if(len(ul) > 0):
                details = ul[0].find_all('a', class_='a-link-normal a-color-tertiary')
                if(len(details) > 0):
                    category = details[-1].text.strip()
                else:
                    category = ""
            else:
                category = ""

            details = soup.find_all('table', id='productDetailsTable')
            if(len(details) > 0):
                length = details[0].find_all('b', text='Print Length:')
                if(len(length) > 0):
                    page_number = length[0].parent.text.split()[2]
                else:
                    page_number = 0

                length = details[0].find_all('b', text='Language:')
                if(len(length) > 0):
                    language = length[0].parent.text.split()[1]
                else:
                    language = ""
            else:
                page_number = pd.np.nan
                language = ""

            dataframe.loc[asin] = (asin, title, category, page_number, language)

        waiting = np.random.rand()
        time.sleep(waiting+1)

    print(defined,',',undefined)
    dataframe.to_csv(amazon_ebooks, header=False,mode='a')
    dataframe = dataframe_original.copy()

# %% [markdown]
# But after some time, we get less and less entries : a message is sent by Amazon when retrieving the page, saying that it's not a good idea to continue scraping data, and that it might be a good idea to go through their API. So, there were some options :
# - we continue to work with the bot while tweaking the parameters to behave like a normal user for the bot (by increasing the waiting time and rotating the user-agent as said before) :
#
# After some online search (https://www.scrapehero.com/how-to-prevent-getting-blacklisted-while-scraping/,
# http://blog.datahut.co/tutorial-how-to-scrape-amazon-using-python-scrapy/,
# http://docs.aws.amazon.com/AWSECommerceService/latest/DG/rest-signature.html,
# https://www.scrapehero.com/tutorial-how-to-scrape-amazon-product-details-using-python/,
# https://blog.hartleybrody.com/scrape-amazon/), we saw that Amazon was detecting the IP, it could ban it, and the solution to avoid it was to use a proxy crawler. As it costs money, we decided not to use that. Furthermore, as said here, it's a legally speaking grey area : https://benbernardblog.com/web-scraping-and-crawling-are-perfectly-legal-right/.
#
# - we try to go through the Amazon API :
#
# For the standard account, we need to put bank account information, so we prefer not to do so. For the student account, as we realized some days before the deadline that it existed, we might consider this option in the future if needed, but we wait for the epfl to accept or not the account request.
#
# - we find a field in the metadata, different from the title, that can help us to merge a book with an ebook :
#
# With some manual analysis, we found a pair of book-ebook :
#
#     {'asin': 'B000JML1QG', 'price': 0.99, 'imUrl': 'http://ecx.images-amazon.com/images/I/41VbZ%2BvxslL._BO2,204,203,200_PIsitb-sticker-v3-big,TopRight,0,-55_SX278_SY278_PIkin4,BottomRight,1,22_AA300_SH20_OU01_.jpg', 'related': {'also_viewed': ['B005LSCQ4Y', 'B0082UXYTE', 'B004TS2B4W'], 'buy_after_viewing': ['B00CS6P31U', 'B005LSCQ4Y', 'B0051EZX8Y', 'B006CRC98G']}, 'categories': [['Books', "Children's Books", 'Fairy Tales, Folk Tales & Myths', 'Anthologies'], ['Books', 'Literature & Fiction'], ['Kindle Store', 'Kindle eBooks', "Children's eBooks", 'Fairy Tales, Folk Tales & Myths', 'Anthologies'], ['Kindle Store', 'Kindle eBooks', "Children's eBooks", 'Fairy Tales, Folk Tales & Myths', 'Collections'], ['Kindle Store', 'Kindle eBooks', 'Literature & Fiction', 'Mythology & Folk Tales'], ['Kindle Store', 'Kindle eBooks', 'Science Fiction & Fantasy', 'Fantasy', 'Fairy Tales']]}
#
#
#     {'asin': '0554319187', 'title': "Grimm's Fairy Stories", 'price': 0.99, 'imUrl': 'http://ecx.images-amazon.com/images/I/41O2olixwXL.jpg', 'related': {'also_viewed': ['1607103133', '0394709306', '1937994317'], 'buy_after_viewing': ['1607103133', '0394709306', '0393088863', '0385189508']}, 'salesRank': {'Books': 2586251}, 'categories': [['Books']]}
#
# As we can see here, the only entry that is the same is the price, and it's dangerous to merge on the price as ebooks are often less expensive than the book version for the same content.
#
# - we find another service that can give us the title for a given asin :
#
# This is the option that we finally chose. The website http://asindb.com/ does exactly that. For this website, there is no bot detection as Amazon does. We can't retrieve the price, the category and the number of pages, but at least we can get the title. We can see the result below :

# %%
if ASINDB_GET_TITLE:
    
    LIMIT = 20
    
    prefix_asindb = 'http://asindb.com/USA/ASIN/'

    dataframe = pd.DataFrame(columns=[['asin', 'title']])
    notdefined = pd.DataFrame(columns=[['asin','notfound']])
    dataframe.to_csv(asindb_ebooks)

    for i, asin in enumerate(ebooks_asin_unique[:LIMIT]):
        r = requests.get(prefix_asindb + asin, headers={'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:23.0) Gecko/20100101 Firefox/23.0'})
        page_body = r.text
        soup = BeautifulSoup(page_body, 'html.parser')

        if i%10 == 0:
            dataframe.to_csv(asindb_ebooks, header=False,mode='a')
            dataframe = pd.DataFrame(columns=[['asin', 'title']])

        notfound = soup.find_all('h6', text = 'No item found!!!')
        if(len(notfound) > 0):
            notdefined.loc[asin] = (asin,1)
        else:
            title = soup.find_all('th', text='Title')
            if(len(title) > 0 and len(title[0].parent.findChildren()) >= 2):
                dataframe.loc[asin] = (asin, title[0].parent.findChildren()[1].text)
            else:
                print('alerte :', asin)

        waiting = np.random.rand()
        time.sleep(waiting+1)

    dataframe.to_csv(asindb_ebooks, header=False,mode='a')
    dataframe = pd.DataFrame(columns=[['asin', 'title']])
    
    print(notdefined.head(2))

# %% [markdown]
# Right above is the undefined entries dataframe (see below for more explanation).
#
# We can see below what kind of output it gives to us.

# %%
ebooks_metadata = read_csv(asindb_ebooks, None)
ebooks_metadata.head()
# Out:
#    Unnamed: 0        asin                                              title
# 0  B000FA64PA  B000FA64PA  Saboteur: Star Wars Legends (Darth Maul) (Shor...
# 1  B000FA64PK  B000FA64PK  Recovery: Star Wars Legends (The New Jedi Orde...
# 2  B000FA64QO  B000FA64QO  Ylesia: Star Wars Legends (The New Jedi Order)...
# 3  B000FBFMVG  B000FBFMVG  A Forest Apart: Star Wars Legends (Short Story...
# 4  B000FC1BN8  B000FC1BN8  Fool's Bargain: Star Wars Legends (Novella) (S...

# %%
read_csv(asindb_ebooks, None).shape[0] # number of titles retrieved
# Out:
# 2741

# %% [markdown]
# This solution is of course not the best one : the asindb website does not contain everything. We have managed to retrieve 2741 titles over 4000 asins by using this technique, but we have no problem with the Amazon bot detection (and possible ban). We can see which entries were not retrieved by printing the notdefined dataframe.
#
# Of course, tu retrieve the 2741 entries, we set the LIMIT constant in the code to be 4000.
#
# We thus continue our analysis by using it.

# %% [markdown]
# Now, as we have the title information for books and ebooks, let's merge them. We read the book metadata information in books_metadata and we have the ebook metadata information with title in ebooks_metadata.

# %%
books_metadata = pd.read_csv(books_metadata_path)
books_metadata.head()
# Out:
#    Unnamed: 0        asin            salesRank   categories  \
# 0           0  0001048791   {'Books': 6334800}  [['Books']]
# 1           1  0001048775  {'Books': 13243226}  [['Books']]
# 2           2  0001048236   {'Books': 8973864}  [['Books']]
# 3           3  0000401048   {'Books': 6448843}  [['Books']]
# 4           4  0001019880   {'Books': 9589258}  [['Books']]
#
#                                                title  price
# 0  The Crucible: Performed by Stuart Pankin, Jero...    NaN
# 1     Measure for Measure: Complete &amp; Unabridged    NaN
# 2               The Sherlock Holmes Audio Collection   9.26
# 3  The rogue of publishers' row;: Confessions of ...    NaN
# 4          Classic Soul Winner's New Testament Bible   5.39

# %% [markdown]
# We merge them on title, and we see that we only get 1297 entries. It's not bad, but we can for sure have a better result. As we can remark, there is a lot of time the title The Space Between. We will discuss later about it.

# %%
#We merge, and get the head. Everything after is here just to have a nicer representation of the first elements
books_metadata.merge(ebooks_metadata, left_on='title', right_on='title').head().iloc[:,[1,7,2,3,4,5]].rename(columns={'asin_x':'asin_books', 'asin_y':'asin_ebooks'})
# Out:
#    asin_books asin_ebooks           salesRank   categories              title  \
# 0  0002008505  B002DYJ7DM  {'Books': 5587764}  [['Books']]  The Space Between
# 1  0615891411  B002DYJ7DM  {'Books': 4145053}  [['Books']]  The Space Between
# 2  1579660584  B002DYJ7DM  {'Books': 2486827}  [['Books']]  The Space Between
# 3  1588515508  B002DYJ7DM  {'Books': 5985767}  [['Books']]  The Space Between
# 4  1595143394  B002DYJ7DM   {'Books': 141638}  [['Books']]  The Space Between
#
#    price
# 0   4.74
# 1   2.99
# 2  20.08
# 3    NaN
# 4   7.13

# %%
books_metadata.merge(ebooks_metadata, left_on='title', right_on='title').shape[0]
# Out:
# 1297

# %% [markdown]
# As we were saying, 1297 is not a big number, and we can do better. We have done the most basic possible thing to do : we have put the title for books and ebooks in lower form (minuscule).

# %%
books_metadata['title'] = books_metadata.title.str.lower()
books_metadata.head()
# Out:
#    Unnamed: 0        asin            salesRank   categories  \
# 0           0  0001048791   {'Books': 6334800}  [['Books']]
# 1           1  0001048775  {'Books': 13243226}  [['Books']]
# 2           2  0001048236   {'Books': 8973864}  [['Books']]
# 3           3  0000401048   {'Books': 6448843}  [['Books']]
# 4           4  0001019880   {'Books': 9589258}  [['Books']]
#
#                                                title  price
# 0  the crucible: performed by stuart pankin, jero...    NaN
# 1     measure for measure: complete &amp; unabridged    NaN
# 2               the sherlock holmes audio collection   9.26
# 3  the rogue of publishers' row;: confessions of ...    NaN
# 4          classic soul winner's new testament bible   5.39

# %%
ebooks_metadata['title'] = ebooks_metadata.title.str.lower()
ebooks_metadata.head()
# Out:
#    Unnamed: 0        asin                                              title
# 0  B000FA64PA  B000FA64PA  saboteur: star wars legends (darth maul) (shor...
# 1  B000FA64PK  B000FA64PK  recovery: star wars legends (the new jedi orde...
# 2  B000FA64QO  B000FA64QO  ylesia: star wars legends (the new jedi order)...
# 3  B000FBFMVG  B000FBFMVG  a forest apart: star wars legends (short story...
# 4  B000FC1BN8  B000FC1BN8  fool's bargain: star wars legends (novella) (s...

# %%
merged_metadatas = books_metadata.merge(ebooks_metadata, left_on='title', right_on='title')
merged_metadatas = merged_metadatas[['asin_x', 'asin_y', 'title', 'price', 'categories', 'salesRank']]
merged_metadatas = merged_metadatas.rename(columns={'asin_x': 'asin_book', 'asin_y': 'asin_ebook'})

# %%
merged_metadatas.head()
# Out:
#     asin_book  asin_ebook              title  price   categories  \
# 0  0002008505  B002DYJ7DM  the space between   4.74  [['Books']]
# 1  0615891411  B002DYJ7DM  the space between   2.99  [['Books']]
# 2  1579660584  B002DYJ7DM  the space between  20.08  [['Books']]
# 3  1588515508  B002DYJ7DM  the space between    NaN  [['Books']]
# 4  1595143394  B002DYJ7DM  the space between   7.13  [['Books']]
#
#             salesRank
# 0  {'Books': 5587764}
# 1  {'Books': 4145053}
# 2  {'Books': 2486827}
# 3  {'Books': 5985767}
# 4   {'Books': 141638}

# %% [markdown]
# As we see, we have a bigger number of entries. We could have tried to increase this number, however as we will see later, we already have some problems with this 'strict' way of doing.

# %%
merged_metadatas.shape[0]
# Out:
# 1506

# %% [markdown]
# So we have merged the two dataframes into one, and it seems that we can do some analysis on it. We have 1506 entries, so it's good for a first analysis in milestone 2 to do so.
# But, as said before, there are title duplicates. It corresponds to books (there is only one duplicate entry for ebooks, for the article 'Second Chances') that have the same title.

# %%
merged_metadatas.head(7)
# Out:
#     asin_book  asin_ebook              title  price   categories  \
# 0  0002008505  B002DYJ7DM  the space between   4.74  [['Books']]
# 1  0615891411  B002DYJ7DM  the space between   2.99  [['Books']]
# 2  1579660584  B002DYJ7DM  the space between  20.08  [['Books']]
# 3  1588515508  B002DYJ7DM  the space between    NaN  [['Books']]
# 4  1595143394  B002DYJ7DM  the space between   7.13  [['Books']]
# 5  1601540817  B002DYJ7DM  the space between  10.99  [['Books']]
# 6  1625530226  B002DYJ7DM  the space between   6.99  [['Books']]
#
#              salesRank
# 0   {'Books': 5587764}
# 1   {'Books': 4145053}
# 2   {'Books': 2486827}
# 3   {'Books': 5985767}
# 4    {'Books': 141638}
# 5  {'Books': 11114107}
# 6   {'Books': 2678708}

# %%
ebooks_metadata.title.describe()
# Out:
# count           2741
# unique          2739
# top       armageddon
# freq               2
# Name: title, dtype: object

# %% [markdown]
# We thus thought that we could consider only pairs that have a unique title in the whole dataframe. In that way, we only have articles that have a unique name, at least in the period in which the dataset has been created, so that we could only have exactly the same content for the book and the ebook.
#
# We thus drop all elements that have a title that exists more than one time in the dataframe.
#
# It's naive, as we don't have all books and ebooks of Amazon, even for the period given, but we wanted to try.

# %%
merged_metadatas = merged_metadatas.drop_duplicates('title',keep=False)
merged_metadatas.head(7)
# Out:
#       asin_book  asin_ebook  \
# 39   0007269854  B003ZUY19I
# 95   0060517689  B0036ZAHDG
# 121  0060595620  B00480P58K
# 173  0060813032  B0049H8X86
# 200  0061084220  B004QS98KU
# 460  0140249249  B003XVYGXK
# 461  0140259678  B003C1R5CA
#
#                                                  title  price   categories  \
# 39                                    the ice princess   7.59  [['Books']]
# 95                                         in the mood   2.99  [['Books']]
# 121                                 the sweetest taboo   8.70  [['Books']]
# 173  dragons from the sea (the strongbow saga, book 2)   3.60  [['Books']]
# 200                                      raven's bride   7.69  [['Books']]
# 460                                               iced    NaN  [['Books']]
# 461                                     a timely death    NaN  [['Books']]
#
#               salesRank
# 39   {'Books': 2527081}
# 95   {'Books': 2663548}
# 121  {'Books': 2956119}
# 173  {'Books': 1269204}
# 200  {'Books': 2911109}
# 460  {'Books': 1225702}
# 461  {'Books': 3077680}

# %% [markdown]
# We now only have 148 elements in the merged collection. We reming the reader about the fact that we tried to obtain 4000 ebooks titles, we got only 2741. By merging, we got 1506 entries, and when we drop all elements that have duplicates, we only have 148 elements.

# %%
merged_metadatas.shape[0]
# Out:
# 148

# %% [markdown]
# After some manual analysis, we have unfortunately seen that for most entries, even if there is only one tuple (asin_book, asin_ebook), the two are not on the same content. We have an example for the first entry (the ice princess) : 'https://www.amazon.com/Princess-Patrik-Hedstrom-Erica-Falck/dp/0007269854' and 'https://www.amazon.com/Ice-Princess-Elizabeth-Hoyt-ebook/dp/B003ZUY19I' have the same title but are written by two different people, and have different content.
#
# There are some tuples that match : for the article 'dragons from the sea (the strongbow saga, book 2)', we have the same content.
#
# It's hard for us to quantify the number of such articles that do not match. We have done some by hand, and we have seen that a lot was not matching at all. A way to have good matches automatically could be to obtain the authors. We think that for the same author, it's rare to have two book with the same name. If we forget a minute about problems like the number of authors which is different for the ebook and the book even if it's the same, or different naming conventions (A fictive example : J. F. Brown or J. Brown), we would need the author information for each book and ebook of the tuples that we have merged.
#
# The website we were <a href='http://asindb.com/'>using</a> does not provide this information. We then need to obtain it from somewhere else.
#
# We have tried to look at the library genesis, using this <a href='http://garbage.world/posts/libgen/'>tutorial</a>. However, there are only two ways to get back information about a book : using a special id (Libgen id), or by date. Furthermore, the asin field exists, but after some tests for which none of the articles had asin, it's hard to say if it's a good option. Thus, we have thought it's not the best solution for us.
#
# We have also been told to look at the Gutenberg project. It could have been a good idea if we could search by asin in the metadatas, that are available. However, it seems that the asin data is not available, so we won't use it neither.

# %%
ebooks_asin_unique
# Out:
# array(['B000F83SZQ', 'B000FA64PA', 'B000FA64PK', ..., 'B00M029T4O',
#        'B00M0RE7CS', 'B00M13FNSS'], dtype=object)

# %%
import bottlenose

# %%
(AWS_ACCESS_KEY_ID,AWS_SECRET_ACCESS_KEY,AWS_ASSOCIATE_TAG) = pd.read_csv('amazon_keys.csv', header=None, usecols=[1]).values.flatten()

# %%
def error_handler(err):
    ex = err['exception']
    if isinstance(ex, HTTPError) and ex.code == 503:
        time.sleep(random.expovariate(0.1))
        return True

# %%
amazon = bottlenose.Amazon(AWS_ACCESS_KEY_ID, AWS_SECRET_ACCESS_KEY, AWS_ASSOCIATE_TAG, ErrorHandler=error_handler)

# %%
keys = '0002178559'#,'.join(ebooks_asin_unique[10:20])

# %%
response = amazon.ItemLookup(ItemId=keys, ResponseGroup="Medium, Offers")
soup = BeautifulSoup(response, 'html.parser')
authors_retrieved = []
#print(soup.prettify())
items = soup.find_all('item')
for item in items[:10]:
    print(item.prettify())

    asin = item.find_all('asin')[0].text
    
    prices = item.find_all('price')
    for price in prices:
        print(price.find('amount').text)
    
    titles = item.find_all('title')
    if(len(titles) != 0):
        title_retrieved = titles[0].text.strip()

    manufacturers = item.find_all('manufacturer')
    if(len(manufacturers) != 0):
        manufacturer_retrieved = manufacturers[0].text.strip()

    authors = item.find_all('author')
    if(len(authors) != 0):
        for author in authors:
            authors_retrieved += [author.text.strip()]
    
    print(asin)
    print(title_retrieved)
    print(authors_retrieved)
    print(manufacturer_retrieved)
    print('--')
# Out:
# <item>
#  <asin>
#   0002178559
#  </asin>
#  <detailpageurl>
#   https://www.amazon.com/Demanding-Impossible-Anarchism-Peter-Marshall/dp/0002178559?SubscriptionId=AKIAIQYRN6QJNHOGZS7Q&amp;tag=mj066-20&amp;linkCode=xm2&amp;camp=2025&amp;creative=165953&amp;creativeASIN=0002178559
#  </detailpageurl>
#  <itemlinks>
#   <itemlink>
#    <description>
#     Technical Details
#    </description>
#    <url>
#     https://www.amazon.com/Demanding-Impossible-Anarchism-Peter-Marshall/dp/tech-data/0002178559?SubscriptionId=AKIAIQYRN6QJNHOGZS7Q&amp;tag=mj066-20&amp;linkCode=xm2&amp;camp=2025&amp;creative=386001&amp;creativeASIN=0002178559
#    </url>
#   </itemlink>
#   <itemlink>
#    <description>
#     Add To Baby Registry
#    </description>
#    <url>
#     https://www.amazon.com/gp/registry/baby/add-item.html?asin.0=0002178559&amp;SubscriptionId=AKIAIQYRN6QJNHOGZS7Q&amp;tag=mj066-20&amp;linkCode=xm2&amp;camp=2025&amp;creative=386001&amp;creativeASIN=0002178559
#    </url>
#   </itemlink>
#   <itemlink>
#    <description>
#     Add To Wedding Registry
#    </description>
#    <url>
#     https://www.amazon.com/gp/registry/wedding/add-item.html?asin.0=0002178559&amp;SubscriptionId=AKIAIQYRN6QJNHOGZS7Q&amp;tag=mj066-20&amp;linkCode=xm2&amp;camp=2025&amp;creative=386001&amp;creativeASIN=0002178559
#    </url>
#   </itemlink>
#   <itemlink>
#    <description>
#     Add To Wishlist
#    </description>
#    <url>
#     https://www.amazon.com/gp/registry/wishlist/add-item.html?asin.0=0002178559&amp;SubscriptionId=AKIAIQYRN6QJNHOGZS7Q&amp;tag=mj066-20&amp;linkCode=xm2&amp;camp=2025&amp;creative=386001&amp;creativeASIN=0002178559
#    </url>
#   </itemlink>
#   <itemlink>
#    <description>
#     Tell A Friend
#    </description>
#    <url>
#     https://www.amazon.com/gp/pdp/taf/0002178559?SubscriptionId=AKIAIQYRN6QJNHOGZS7Q&amp;tag=mj066-20&amp;linkCode=xm2&amp;camp=2025&amp;creative=386001&amp;creativeASIN=0002178559
#    </url>
#   </itemlink>
#   <itemlink>
#    <description>
#     All Customer Reviews
#    </description>
#    <url>
#     https://www.amazon.com/review/product/0002178559?SubscriptionId=AKIAIQYRN6QJNHOGZS7Q&amp;tag=mj066-20&amp;linkCode=xm2&amp;camp=2025&amp;creative=386001&amp;creativeASIN=0002178559
#    </url>
#   </itemlink>
#   <itemlink>
#    <description>
#     All Offers
#    </description>
#    <url>
#     https://www.amazon.com/gp/offer-listing/0002178559?SubscriptionId=AKIAIQYRN6QJNHOGZS7Q&amp;tag=mj066-20&amp;linkCode=xm2&amp;camp=2025&amp;creative=386001&amp;creativeASIN=0002178559
#    </url>
#   </itemlink>
#  </itemlinks>
#  <salesrank>
#   5017541
#  </salesrank>
#  <smallimage>
#   <url>
#    https://images-na.ssl-images-amazon.com/images/I/411zwi9OAXL._SL75_.jpg
#   </url>
#   <height units="pixels">
#    56
#   </height>
#   <width units="pixels">
#    75
#   </width>
#  </smallimage>
#  <mediumimage>
#   <url>
#    https://images-na.ssl-images-amazon.com/images/I/411zwi9OAXL._SL160_.jpg
#   </url>
#   <height units="pixels">
#    120
#   </height>
#   <width units="pixels">
#    160
#   </width>
#  </mediumimage>
#  <largeimage>
#   <url>
#    https://images-na.ssl-images-amazon.com/images/I/411zwi9OAXL.jpg
#   </url>
#   <height units="pixels">
#    375
#   </height>
#   <width units="pixels">
#    500
#   </width>
#  </largeimage>
#  <imagesets>
#   <imageset category="primary">
#    <swatchimage>
#     <url>
#      https://images-na.ssl-images-amazon.com/images/I/411zwi9OAXL._SL30_.jpg
#     </url>
#     <height units="pixels">
#      22
#     </height>
#     <width units="pixels">
#      30
#     </width>
#    </swatchimage>
#    <smallimage>
#     <url>
#      https://images-na.ssl-images-amazon.com/images/I/411zwi9OAXL._SL75_.jpg
#     </url>
#     <height units="pixels">
#      56
#     </height>
#     <width units="pixels">
#      75
#     </width>
#    </smallimage>
#    <thumbnailimage>
#     <url>
#      https://images-na.ssl-images-amazon.com/images/I/411zwi9OAXL._SL75_.jpg
#     </url>
#     <height units="pixels">
#      56
#     </height>
#     <width units="pixels">
#      75
#     </width>
#    </thumbnailimage>
#    <tinyimage>
#     <url>
#      https://images-na.ssl-images-amazon.com/images/I/411zwi9OAXL._SL110_.jpg
#     </url>
#     <height units="pixels">
#      82
#     </height>
#     <width units="pixels">
#      110
#     </width>
#    </tinyimage>
#    <mediumimage>
#     <url>
#      https://images-na.ssl-images-amazon.com/images/I/411zwi9OAXL._SL160_.jpg
#     </url>
#     <height units="pixels">
#      120
#     </height>
#     <width units="pixels">
#      160
#     </width>
#    </mediumimage>
#    <largeimage>
#     <url>
#      https://images-na.ssl-images-amazon.com/images/I/411zwi9OAXL.jpg
#     </url>
#     <height units="pixels">
#      375
#     </height>
#     <width units="pixels">
#      500
#     </width>
#    </largeimage>
#    <hiresimage>
#     <url>
#      https://images-na.ssl-images-amazon.com/images/I/61Ufn5kWy9L.jpg
#     </url>
#     <height units="pixels">
#      768
#     </height>
#     <width units="pixels">
#      1024
#     </width>
#    </hiresimage>
#   </imageset>
#  </imagesets>
#  <itemattributes>
#   <author>
#    Peter H. Marshall
#   </author>
#   <binding>
#    Hardcover
#   </binding>
#   <ean>
#    9780002178556
#   </ean>
#   <eanlist>
#    <eanlistelement>
#     9780002178556
#    </eanlistelement>
#   </eanlist>
#   <edition>
#    0
#   </edition>
#   <isbn>
#    0002178559
#   </isbn>
#   <label>
#    HarperCollins
#   </label>
#   <languages>
#    <language>
#     <name>
#      English
#     </name>
#     <type>
#      Published
#     </type>
#    </language>
#    <language>
#     <name>
#      English
#     </name>
#     <type>
#      Original Language
#     </type>
#    </language>
#    <language>
#     <name>
#      English
#     </name>
#     <type>
#      Unknown
#     </type>
#    </language>
#   </languages>
#   <listprice>
#    <amount>
#     4233
#    </amount>
#    <currencycode>
#     USD
#    </currencycode>
#    <formattedprice>
#     $42.33
#    </formattedprice>
#   </listprice>
#   <manufacturer>
#    HarperCollins
#   </manufacturer>
#   <numberofitems>
#    1
#   </numberofitems>
#   <numberofpages>
#    778
#   </numberofpages>
#   <packagedimensions>
#    <height units="hundredths-inches">
#     260
#    </height>
#    <length units="hundredths-inches">
#     929
#    </length>
#    <weight units="Hundredths Pounds">
#     309
#    </weight>
#    <width units="hundredths-inches">
#     614
#    </width>
#   </packagedimensions>
#   <productgroup>
#    Book
#   </productgroup>
#   <producttypename>
#    ABIS_BOOK
#   </producttypename>
#   <publicationdate>
#    1991-05-01
#   </publicationdate>
#   <publisher>
#    HarperCollins
#   </publisher>
#   <studio>
#    HarperCollins
#   </studio>
#   <title>
#    Demanding the Impossible: A History of Anarchism
#   </title>
#  </itemattributes>
#  <offersummary>
#   <lowestnewprice>
#    <amount>
#     26008
#    </amount>
#    <currencycode>
#     USD
#    </currencycode>
#    <formattedprice>
#     $260.08
#    </formattedprice>
#   </lowestnewprice>
#   <lowestusedprice>
#    <amount>
#     14176
#    </amount>
#    <currencycode>
#     USD
#    </currencycode>
#    <formattedprice>
#     $141.76
#    </formattedprice>
#   </lowestusedprice>
#   <totalnew>
#    1
#   </totalnew>
#   <totalused>
#    5
#   </totalused>
#   <totalcollectible>
#    0
#   </totalcollectible>
#   <totalrefurbished>
#    0
#   </totalrefurbished>
#  </offersummary>
#  <offers>
#   <totaloffers>
#    0
#   </totaloffers>
#   <totalofferpages>
#    0
#   </totalofferpages>
#   <moreoffersurl>
#    0
#   </moreoffersurl>
#  </offers>
#  <editorialreviews>
#   <editorialreview>
#    <source>
#     Product Description
#    </source>
#    <content>
#     Anarchism is a philosophical and political creed which many individuals have subscribed to over the centuries, and for which many have been persecuted by other more authoritive ideologies like fascism and state socialism. There have been anarchist-inspired revolutions - in Spain, in the Ukraine, in Mexico - which have in turn led to (however short-lived) anarchist administrations. But anarchism's power has, first and foremost, been the power of the lone protestor, the dissenter who is unafraid to expose himself to reprisal for the sake of preaching the real gospel of liberty, equality and fraternity which so many so-called revolutionaries usually leave in tatters once they graduate from barricades to corridors of power. The author argues that the spirit of anarchism is in the voice of Tolstoy, of Gandhi, of Bakunin and of Godwin, of Camus and of Chomsky.
#    </content>
#    <islinksuppressed>
#     0
#    </islinksuppressed>
#   </editorialreview>
#  </editorialreviews>
# </item>
# 0002178559
# Demanding the Impossible: A History of Anarchism
# ['Peter H. Marshall']
# HarperCollins
# --

# %%
len(soup.find_all('itemattributes'))
# Out:
# 6

# %%
BeautifulSoup(response, 'html.parser').prettify()
# Out:
# '<?xml version="1.0" ?>\n<itemlookupresponse xmlns="http://webservices.amazon.com/AWSECommerceService/2013-08-01">\n <operationrequest>\n  <httpheaders>\n   <header name="UserAgent" value="Python-urllib/3.6">\n   </header>\n  </httpheaders>\n  <requestid>\n   926a1e48-cba2-4483-8e34-d6fecf311abf\n  </requestid>\n  <arguments>\n   <argument name="AWSAccessKeyId" value="AKIAIQYRN6QJNHOGZS7Q">\n   </argument>\n   <argument name="AssociateTag" value="mj066-20">\n   </argument>\n   <argument name="ItemId" value="B000F83SZQ">\n   </argument>\n   <argument name="Operation" value="ItemLookup">\n   </argument>\n   <argument name="Service" value="AWSECommerceService">\n   </argument>\n   <argument name="Timestamp" value="2017-12-11T15:20:38Z">\n   </argument>\n   <argument name="Version" value="2013-08-01">\n   </argument>\n   <argument name="Signature" value="43RaHSog3IF2WPzYszFHJHLw7htznSRe/tVVdoKGGZ8=">\n   </argument>\n  </arguments>\n  <requestprocessingtime>\n   0.0801388650000000\n  </requestprocessingtime>\n </operationrequest>\n <items>\n  <request>\n   <isvalid>\n    True\n   </isvalid>\n   <itemlookuprequest>\n    <idtype>\n     ASIN\n    </idtype>\n    <itemid>\n     B000F83SZQ\n    </itemid>\n    <responsegroup>\n     Small\n    </responsegroup>\n    <variationpage>\n     All\n    </variationpage>\n   </itemlookuprequest>\n  </request>\n  <item>\n   <asin>\n    B000F83SZQ\n   </asin>\n   <detailpageurl>\n    https://www.amazon.com/Matter-Policy-Amy-Brewster-Mystery-ebook/dp/B000F83SZQ?SubscriptionId=AKIAIQYRN6QJNHOGZS7Q&amp;tag=mj066-20&amp;linkCode=xm2&amp;camp=2025&amp;creative=165953&amp;creativeASIN=B000F83SZQ\n   </detailpageurl>\n   <itemlinks>\n    <itemlink>\n     <description>\n      Technical Details\n     </description>\n     <url>\n      https://www.amazon.com/Matter-Policy-Amy-Brewster-Mystery-ebook/dp/tech-data/B000F83SZQ?SubscriptionId=AKIAIQYRN6QJNHOGZS7Q&amp;tag=mj066-20&amp;linkCode=xm2&amp;camp=2025&amp;creative=386001&amp;creativeASIN=B000F83SZQ\n     </url>\n    </itemlink>\n    <itemlink>\n     <description>\n      Add To Baby Registry\n     </description>\n     <url>\n      https://www.amazon.com/gp/registry/baby/add-item.html?asin.0=B000F83SZQ&amp;SubscriptionId=AKIAIQYRN6QJNHOGZS7Q&amp;tag=mj066-20&amp;linkCode=xm2&amp;camp=2025&amp;creative=386001&amp;creativeASIN=B000F83SZQ\n     </url>\n    </itemlink>\n    <itemlink>\n     <description>\n      Add To Wedding Registry\n     </description>\n     <url>\n      https://www.amazon.com/gp/registry/wedding/add-item.html?asin.0=B000F83SZQ&amp;SubscriptionId=AKIAIQYRN6QJNHOGZS7Q&amp;tag=mj066-20&amp;linkCode=xm2&amp;camp=2025&amp;creative=386001&amp;creativeASIN=B000F83SZQ\n     </url>\n    </itemlink>\n    <itemlink>\n     <description>\n      Add To Wishlist\n     </description>\n     <url>\n      https://www.amazon.com/gp/registry/wishlist/add-item.html?asin.0=B000F83SZQ&amp;SubscriptionId=AKIAIQYRN6QJNHOGZS7Q&amp;tag=mj066-20&amp;linkCode=xm2&amp;camp=2025&amp;creative=386001&amp;creativeASIN=B000F83SZQ\n     </url>\n    </itemlink>\n    <itemlink>\n     <description>\n      Tell A Friend\n     </description>\n     <url>\n      https://www.amazon.com/gp/pdp/taf/B000F83SZQ?SubscriptionId=AKIAIQYRN6QJNHOGZS7Q&amp;tag=mj066-20&amp;linkCode=xm2&amp;camp=2025&amp;creative=386001&amp;creativeASIN=B000F83SZQ\n     </url>\n    </itemlink>\n    <itemlink>\n     <description>\n      All Customer Reviews\n     </description>\n     <url>\n      https://www.amazon.com/review/product/B000F83SZQ?SubscriptionId=AKIAIQYRN6QJNHOGZS7Q&amp;tag=mj066-20&amp;linkCode=xm2&amp;camp=2025&amp;creative=386001&amp;creativeASIN=B000F83SZQ\n     </url>\n    </itemlink>\n    <itemlink>\n     <description>\n      All Offers\n     </description>\n     <url>\n      https://www.amazon.com/gp/offer-listing/B000F83SZQ?SubscriptionId=AKIAIQYRN6QJNHOGZS7Q&amp;tag=mj066-20&amp;linkCode=xm2&amp;camp=2025&amp;creative=386001&amp;creativeASIN=B000F83SZQ\n     </url>\n    </itemlink>\n   </item ...

# %%
soup = BeautifulSoup(response, 'html.parser')

# %%
authors_retrieved = []


titles = soup.find_all('title')
if(len(titles) != 0):
    title_retrieved = titles[0].text.strip()

manufacturers = soup.find_all('manufacturer')
if(len(manufacturers) != 0):
    manufacturer_retrieved = manufacturers[0].text.strip()

authors = soup.find_all('author')
if(len(authors) != 0):
    for author in authors:
        authors_retrieved += [author.text.strip()]

print(title_retrieved)
print(authors_retrieved)
print(manufacturer_retrieved)
# Out:
# A Matter of Policy [An Amy Brewster Mystery]
# ['Sam Merwin Jr.']
# PageTurner

# %%
responsebis = amazon.ItemLookup(ItemId=ebooks_asin_unique[1])

# %%
soup = BeautifulSoup(responsebis, 'html.parser')

# %%
soup.prettify()#.find('itemattributes')
# Out:
# '<?xml version="1.0" ?>\n<itemlookupresponse xmlns="http://webservices.amazon.com/AWSECommerceService/2013-08-01">\n <operationrequest>\n  <httpheaders>\n   <header name="UserAgent" value="Python-urllib/3.6">\n   </header>\n  </httpheaders>\n  <requestid>\n   35c7eb60-19f8-4ef6-ad82-579a10537759\n  </requestid>\n  <arguments>\n   <argument name="AWSAccessKeyId" value="AKIAIQYRN6QJNHOGZS7Q">\n   </argument>\n   <argument name="AssociateTag" value="mj066-20">\n   </argument>\n   <argument name="ItemId" value="B000FA64PA">\n   </argument>\n   <argument name="Operation" value="ItemLookup">\n   </argument>\n   <argument name="Service" value="AWSECommerceService">\n   </argument>\n   <argument name="Timestamp" value="2017-12-04T22:11:03Z">\n   </argument>\n   <argument name="Version" value="2013-08-01">\n   </argument>\n   <argument name="Signature" value="04tXLiapiuPH0/CiGX22iPOkm2Ui/C+MEmRWCfPjIAc=">\n   </argument>\n  </arguments>\n  <requestprocessingtime>\n   0.0793014240000000\n  </requestprocessingtime>\n </operationrequest>\n <items>\n  <request>\n   <isvalid>\n    True\n   </isvalid>\n   <itemlookuprequest>\n    <idtype>\n     ASIN\n    </idtype>\n    <itemid>\n     B000FA64PA\n    </itemid>\n    <responsegroup>\n     Small\n    </responsegroup>\n    <variationpage>\n     All\n    </variationpage>\n   </itemlookuprequest>\n  </request>\n  <item>\n   <asin>\n    B000FA64PA\n   </asin>\n   <detailpageurl>\n    https://www.amazon.com/Saboteur-Legends-Darth-Short-Story-ebook/dp/B000FA64PA?SubscriptionId=AKIAIQYRN6QJNHOGZS7Q&amp;tag=mj066-20&amp;linkCode=xm2&amp;camp=2025&amp;creative=165953&amp;creativeASIN=B000FA64PA\n   </detailpageurl>\n   <itemlinks>\n    <itemlink>\n     <description>\n      Technical Details\n     </description>\n     <url>\n      https://www.amazon.com/Saboteur-Legends-Darth-Short-Story-ebook/dp/tech-data/B000FA64PA?SubscriptionId=AKIAIQYRN6QJNHOGZS7Q&amp;tag=mj066-20&amp;linkCode=xm2&amp;camp=2025&amp;creative=386001&amp;creativeASIN=B000FA64PA\n     </url>\n    </itemlink>\n    <itemlink>\n     <description>\n      Add To Baby Registry\n     </description>\n     <url>\n      https://www.amazon.com/gp/registry/baby/add-item.html?asin.0=B000FA64PA&amp;SubscriptionId=AKIAIQYRN6QJNHOGZS7Q&amp;tag=mj066-20&amp;linkCode=xm2&amp;camp=2025&amp;creative=386001&amp;creativeASIN=B000FA64PA\n     </url>\n    </itemlink>\n    <itemlink>\n     <description>\n      Add To Wedding Registry\n     </description>\n     <url>\n      https://www.amazon.com/gp/registry/wedding/add-item.html?asin.0=B000FA64PA&amp;SubscriptionId=AKIAIQYRN6QJNHOGZS7Q&amp;tag=mj066-20&amp;linkCode=xm2&amp;camp=2025&amp;creative=386001&amp;creativeASIN=B000FA64PA\n     </url>\n    </itemlink>\n    <itemlink>\n     <description>\n      Add To Wishlist\n     </description>\n     <url>\n      https://www.amazon.com/gp/registry/wishlist/add-item.html?asin.0=B000FA64PA&amp;SubscriptionId=AKIAIQYRN6QJNHOGZS7Q&amp;tag=mj066-20&amp;linkCode=xm2&amp;camp=2025&amp;creative=386001&amp;creativeASIN=B000FA64PA\n     </url>\n    </itemlink>\n    <itemlink>\n     <description>\n      Tell A Friend\n     </description>\n     <url>\n      https://www.amazon.com/gp/pdp/taf/B000FA64PA?SubscriptionId=AKIAIQYRN6QJNHOGZS7Q&amp;tag=mj066-20&amp;linkCode=xm2&amp;camp=2025&amp;creative=386001&amp;creativeASIN=B000FA64PA\n     </url>\n    </itemlink>\n    <itemlink>\n     <description>\n      All Customer Reviews\n     </description>\n     <url>\n      https://www.amazon.com/review/product/B000FA64PA?SubscriptionId=AKIAIQYRN6QJNHOGZS7Q&amp;tag=mj066-20&amp;linkCode=xm2&amp;camp=2025&amp;creative=386001&amp;creativeASIN=B000FA64PA\n     </url>\n    </itemlink>\n    <itemlink>\n     <description>\n      All Offers\n     </description>\n     <url>\n      https://www.amazon.com/gp/offer-listing/B000FA64PA?SubscriptionId=AKIAIQYRN6QJNHOGZS7Q&amp;tag=mj066-20&amp;linkCode=xm2&amp;camp=2025&amp;creative=386001&amp;creativeASIN=B000FA64PA\n     </url>\n    </itemlink>\n   </item ...

# %%
authors_retrieved = []


titles = soup.find_all('title')
if(len(titles) != 0):
    title_retrieved = titles[0].text.strip()

manufacturers = soup.find_all('manufacturer')
if(len(manufacturers) != 0):
    manufacturer_retrieved = manufacturers[0].text.strip()

authors = soup.find_all('author')
if(len(authors) != 0):
    for author in authors:
        authors_retrieved += [author.text.strip()]

print(title_retrieved)
print(authors_retrieved)
print(manufacturer_retrieved)
# Out:
# Saboteur: Star Wars Legends (Darth Maul) (Short Story) (Star Wars: Darth Maul Book 1)
# ['James Luceno', 'Ron Marz', 'Jan Duursema', 'Rick Magyar', 'Drew Struzan']
# Del Rey

# %%
[ebooks_asin_unique[0], title_retrieved, 
                                          ['James Luceno', 'Ron Marz', 'Jan Duursema', 'Rick Magyar', 'Drew Struzan'], manufacturer_retrieved]
# Out:
# ['B000F83SZQ',
#  'Saboteur: Star Wars Legends (Darth Maul) (Short Story) (Star Wars: Darth Maul Book 1)',
#  ['James Luceno', 'Ron Marz', 'Jan Duursema', 'Rick Magyar', 'Drew Struzan'],
#  'Del Rey']

# %%
pd.DataFrame({'title':title_retrieved,'authors':", ".join(['James Luceno', 'Ron Marz', 'Jan Duursema', 'Rick Magyar', 'Drew Struzan']), 'manufacturer':manufacturer_retrieved},index=[ebooks_asin_unique[0]])
# Out:
#                                                       authors manufacturer  \
# B000F83SZQ  James Luceno, Ron Marz, Jan Duursema, Rick Mag...      Del Rey
#
#                                                         title
# B000F83SZQ  Saboteur: Star Wars Legends (Darth Maul) (Shor...

# %%
dataframe_ebooks = pd.DataFrame(columns=['title', 'authors', 'manufacturer'])

# %%
new_entry = pd.DataFrame({'title':title_retrieved,'authors':", ".join(['James Luceno', 'Ron Marz', 'Jan Duursema', 'Rick Magyar', 'Drew Struzan']), 'manufacturer':manufacturer_retrieved},index=[ebooks_asin_unique[0]])
dataframe_ebooks = dataframe_ebooks.append(new_entry)
#dataframe_ebooks.append({'asin':ebooks_asin_unique[0], 'title':title_retrieved, 
#                                          'authors':authors_retrieved, 'manufacturer':manufacturer_retrieved}, ignore_index=True)
dataframe_ebooks[['title', 'authors', 'manufacturer']]
# Out:
#                                                         title  \
# B000F83SZQ  Saboteur: Star Wars Legends (Darth Maul) (Shor...
#
#                                                       authors manufacturer
# B000F83SZQ  James Luceno, Ron Marz, Jan Duursema, Rick Mag...      Del Rey

# %%
#dataframe_undefined = pd.Series()

#dataframe_undefined.to_csv(amazon_aws_ebooks_undefined)

#dataframe_undefined = dataframe_undefined.append(pd.Series(ebooks_asin_unique[0]))
#dataframe_undefined = dataframe_undefined.append(pd.Series(ebooks_asin_unique[1]))

#dataframe_undefined.to_csv(amazon_aws_ebooks_undefined, header=False,mode='a')

# %%
new_entry = pd.DataFrame({'title':'','authors':", ".join([]), 'manufacturer':''},index=['111'])
dataframe_ebooks = dataframe_ebooks.append(new_entry)
dataframe_ebooks[['title', 'authors', 'manufacturer']].dropna(thresh=1, subset=[], inplace=False)
# Out:
# Empty DataFrame
# Columns: [title, authors, manufacturer]
# Index: []

# %%
log = pd.Series()
log = log.append(pd.Series(BeautifulSoup(responsebis, 'html.parser').prettify()))

# %%
log
# Out:
# 0    <?xml version="1.0" ?>\n<itemlookupresponse xm...
# dtype: object

# %%
#dataframe_undefined = pd.DataFrame(columns=['title', 'authors', 'manufacturer'])
#dataframe_undefined.to_csv(amazon_aws_ebooks_undefined)

# %%
import bottlenose

# %%
(AWS_ACCESS_KEY_ID,AWS_SECRET_ACCESS_KEY,AWS_ASSOCIATE_TAG) = pd.read_csv('amazon_keys.csv', header=None, usecols=[1]).values.flatten()

# %%
import random
import time
from urllib.error import HTTPError

def error_handler(err):
    ex = err['exception']
    if (isinstance(ex, HTTPError) and ex.code == 503) or isinstance(ex, TimeoutError):
        time.sleep(random.expovariate(0.1))
        return True

# %%
amazon = bottlenose.Amazon(AWS_ACCESS_KEY_ID, AWS_SECRET_ACCESS_KEY, AWS_ASSOCIATE_TAG, ErrorHandler=error_handler)

# %%
BEGIN = len(ebooks_asin_unique)
END = len(ebooks_asin_unique)
SIMULTANEOUS_REQUESTS = 10
STEP = 50
override = False

# %% [markdown]
# There are entries that are still not available through the Advertising API : B000FC26RI
#
# Also newspaper don't comply to this contract of authors : The Wall Street Journal (B000FDJ0FS)

# %%
dataframe_ebooks = pd.DataFrame(columns=['title', 'authors', 'manufacturer', 'rank', 'price', 'currency', 'reldate', 'page', 'language'])
dataframe_undefined = pd.DataFrame(columns=['title', 'authors', 'manufacturer', 'rank', 'price', 'currency', 'reldate', 'page', 'language'])
log = pd.Series()

if(override):
    dataframe_ebooks.to_csv(amazon_aws_ebooks)
    dataframe_undefined.to_csv(amazon_aws_ebooks_undefined)
    log.to_csv(amazon_aws_ebooks_log)

ebooks_simultaneous_list = []

for i, ebook_asin in enumerate(ebooks_asin_unique[BEGIN:END]):
    ebooks_simultaneous_list += [ebook_asin]
    
    if i>0 and i%SIMULTANEOUS_REQUESTS == 0:
        keys = ','.join(ebooks_simultaneous_list)
        ebooks_simultaneous_list = []
        if i%STEP==0 and i > 0:
            print(i+BEGIN)
            dataframe_ebooks[['title', 'authors', 'manufacturer', 'rank', 'price', 'currency', 'reldate', 'page', 'language']].to_csv(amazon_aws_ebooks, header=False,mode='a')
            dataframe_ebooks = pd.DataFrame(columns=['title', 'authors', 'manufacturer', 'rank', 'price', 'currency', 'reldate', 'page', 'language'])

            dataframe_undefined[['title', 'authors', 'manufacturer', 'rank', 'price', 'currency', 'reldate', 'page', 'language']].to_csv(amazon_aws_ebooks_undefined, header=False,mode='a')
            dataframe_undefined = pd.DataFrame(columns=['title', 'authors', 'manufacturer', 'rank', 'price', 'currency', 'reldate', 'page', 'language'])

            log.to_csv(amazon_aws_ebooks_log, header=False,mode='a')
            log = pd.Series()

        response = amazon.ItemLookup(ItemId=keys, ResponseGroup="Medium, Offers")
        soup = BeautifulSoup(response, 'html.parser')
        
        items = soup.find_all('item')
        for item in items:
            all_important_defined = True
            authors_retrieved = []
            
            asins = item.find_all('asin')
            if(len(asins) != 0):
                asin_retrieved = asins[0].text.strip()
            else:
                asin_retrieved = ''
                all_important_defined = False
                
            salesRanks = item.find_all('salesrank')
            if(len(salesRanks) != 0):
                salesRank_retrieved = salesRanks[0].text.strip()
            else:
                salesRank_retrieved = ''
                #all_important_defined = False
                
            offers = item.find_all('offer')
            price_got = False
            for offer in offers:
                conditions = offer.find_all('condition')
                if(len(conditions) > 0 and conditions[0].text == 'New'):
                    prices = offer.find_all('amount')
                    curr_codes = offer.find_all('currencycode')
                    if(len(prices) > 0 and len(curr_codes) > 0):
                        price_retrieved = prices[0].text
                        curr_retrieved = curr_codes[0].text
                        price_got = True
                       
            if(not price_got):
                price_retrieved = ''
                curr_retrieved = ''
                #all_important_defined = False
                
            
            releaseDates = item.find_all('releasedate')
            if(len(releaseDates) != 0):
                reldate_retrieved = releaseDates[0].text.strip()
            else:
                reldate_retrieved = ''
                all_important_defined = False
                
            pages = item.find_all('numberofpages')
            if(len(pages) != 0):
                page_retrieved = pages[0].text.strip()
            else:
                page_retrieved = ''
                #all_important_defined = False
            
            languages = item.find_all('language')
            if(len(languages) != 0):
                language_retrieved = languages[0].find('name').text.strip()
            else:
                language_retrieved = ''
                #all_important_defined = False
                

            titles = item.find_all('title')
            if(len(titles) != 0):
                title_retrieved = titles[0].text.strip()
            else:
                title_retrieved = ''
                all_important_defined = False

            manufacturers = item.find_all('manufacturer')
            if(len(manufacturers) != 0):
                manufacturer_retrieved = manufacturers[0].text.strip()
            else:
                manufacturer_retrieved = ''

            authors = item.find_all('author')
            if(len(authors) != 0):
                for author in authors:
                    authors_retrieved += [author.text.strip()]
            else:
                authors_retrieved = []
                all_important_defined = False

            new_entry = pd.DataFrame({'title':title_retrieved,'authors':", ".join(authors_retrieved), 'manufacturer':manufacturer_retrieved, 'rank': salesRank_retrieved, 'price':price_retrieved, 'currency':curr_retrieved, 'reldate':reldate_retrieved, 'page': page_retrieved, 'language': language_retrieved},index=[asin_retrieved])
            if(all_important_defined):
                dataframe_ebooks = dataframe_ebooks.append(new_entry)
            else:
                dataframe_undefined = dataframe_undefined.append(new_entry)
                log = log.append(pd.Series(item.prettify()))

dataframe_ebooks[['title', 'authors', 'manufacturer', 'rank', 'price', 'currency', 'reldate', 'page', 'language']].to_csv(amazon_aws_ebooks, header=False,mode='a')
dataframe_undefined[['title', 'authors', 'manufacturer', 'rank', 'price', 'currency', 'reldate', 'page', 'language']].to_csv(amazon_aws_ebooks_undefined, header=False,mode='a')
log.to_csv(amazon_aws_ebooks_log, header=False,mode='a')
# Out:
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2550
# 2600
# 2650
# 2700
# 2750
# 2800
# 2850
# 2900
# 2950
# 3000
# 3050
# 3100
# 3150
# 3200
# 3250
# 3300
# 3350
# 3400
# 3450
# 3500
# 3550
# 3600
# 3650
# 3700
# 3750
# 3800
# 3850
# 3900
# 3950
# 4000
# 4050
# 4100
# 4150
# 4200
# 4250
# 4300
# 4350
# 4400
# 4450
# 4500
# 4550
# 4600
# 4650
# 4700
# 4750
# 4800
# 4850
# 4900
# 4950
# 5000
# 5050
# 5100
# 5150
# 5200
# 5250
# 5300
# 5350
# 5400
# 5450
# 5500
# 5550
# 5600
# 5650
# 5700
# 5750
# 5800
# 5850
# 5900
# 5950
# 6000
# 6050
# 6100
# 6150
# 6200
# 6250
# 6300
# 6350
# 6400
# 6450
# 6500
# 6550
# 6600
# 6650
# 6700
# 6750
# 6800
# 6850
# 6900
# 6950
# 7000
# 7050
# 7100
# 7150
# 7200
# 7250
# 7300
# 7350
# 7400
# 7450
# 7500
# 7550
# 7600
# 7650
# 7700
# 7750
# 7800
# 7850
# 7900
# 7950
# 8000
# 8050
# 8100
# 8150
# 8200
# 8250
# 8300
# 8350
# 8400
# 8450
# 8500
# 8550
# 8600
# 8650
# 8700
# 8750
# 8800
# 8850
# 8900
# 8950
# 9000
# 9050
# 9100
# 9150
# 9200
# 9250
# 9300
# 9350
# 9400
# 9450
# 9500
# 9550
# 9600
# 9650
# 9700
# 9750
# 9800
# 9850
# 9900
# 9950
# 10000
# 10050
# 10100
# 10150
# 10200
# 10250
# 10300
# 10350
# 10400
# 10450
# 10500
# 10550
# 10600
# 10650
# 10700
# 10750
# 10800
# 10850
# 10900
# 10950
# 11000
# 11050
# 11100
# 11150
# 11200
# 11250
# 11300
# 11350
# 11400
# 11450
# 11500
# 11550
# 11600
# 11650
# 11700
# 11750
# 11800
# 11850
# 11900
# 11950
# 12000
# 12050
# 12100
# 12150
# 12200
# 12250
# 12300
# 12350
# 12400
# 12450
# 12500
# 12550
# 12600
# 12650
# 12700
# 12750
# 12800
# 12850
# 12900
# 12950
# 13000
# 13050
# 13100
# 13150
# 13200
# 13250
# 13300
# 13350
# 13400
# 13450
# 13500
# 13550
# 13600
# 13650
# 13700
# 13750
# 13800
# 13850
# 13900
# 13950
# 14000
# 14050
# 14100
# 14150
# 14200
# 14250
# 14300
# 14350
# 14400
# 14450
# 14500
# 14550
# 14600
# 14650
# 14700
# 14750
# 14800
# 14850
# 14900
# 14950
# 15000
# 15050
# 15100
# 15150
# 15200
# 15250
# 15300
# 15350
# 15400
# 15450
# 15500
# 15550
# 15600
# 15650
# 15700
# 15750
# 15800
# 15850
# 15900
# 15950
# 16000
# 16050
# 16100
# 16150
# 16200
# 16250
# 16300
# 16350
# 16400
# 16450
# 16500
# 16550
# 16600
# 16650
# 16700
# 16750
# 16800
# 16850
# 16900
# 16950
# 17000
# 17050
# 17100
# 17150
# 17200
# 17250
# 17300
# 17350
# 17400
# 17450
# 17500
# 17550
# 17600
# 17650
# 17700
# 17750
# 17800
# 17850
# 17900
# 17950
# 18000
# 18050
# 18100
# 18150
# 18200
# 18250
# 18300
# 18350
# 18400
# 18450
# 18500
# 18550
# 18600
# 18650
# 18700
# 18750
# 18800
# 18850
# 18900
# 18950
# 19000
# 19050
# 19100
# 19150
# 19200
# 19250
# 19300
# 19350
# 19400
# 19450
# 19500
# 19550
# 19600
# 19650
# 19700
# 19750
# 19800
# 19850
# 19900
# 19950
# 20000
# 20050
# 20100
# 20150
# 20200
# 20250
# 20300
# 20350
# 20400
# 20450
# 20500
# 20550
# 20600
# 20650
# 20700
# 20750
# 20800
# 20850
# 20900
# 20950
# 21000
# 21050
# 21100
# 21150
# 21200
# 21250
# 21300
# 21350
# 21400
# 21450
# 21500
# 21550
# 21600
# 21650
# 21700
# 21750
# 21800
# 21850
# 21900
# 21950
# 22000
# 22050
# 22100
# 22150
# 22200
# 22250
# 22300
# 22350
# 22400
# 22450
# 22500
# 22550
# 22600
# 22650
# 22700
# 22750
# 22800
# 22850
# 22900
# 22950
# 23000
# 23050
# 23100
# 23150
# 23200
# 23250
# 23300
# 23350
# 23400
# 23450
# 23500
# 23550
# 23600
# 23650
# 23700
# 23750
# 23800
# 23850
# 23900
# 23950
# 24000
# 24050
# 24100
# 24150
# 24200
# 24250
# 24300
# 24350
# 24400
# 24450
# 24500
# 24550
# 24600
# 24650
# 24700
# 24750
# 24800
# 24850
# 24900
# 24950
# 25000
# 25050
# 25100
# 25150
# 25200
# 25250
# 25300
# 25350
# 25400
# 25450
# 25500
# 25550
# 25600
# 25650
# 25700
# 25750
# 25800
# 25850
# 25900
# 25950
# 26000
# 26050
# 26100
# 26150
# 26200
# 26250
# 26300
# 26350
# 26400
# 26450
# 26500
# 26550
# 26600
# 26650
# 26700
# 26750
# 26800
# 26850
# 26900
# 26950
# 27000
# 27050
# 27100
# 27150
# 27200
# 27250
# 27300
# 27350
# 27400
# 27450
# 27500
# 27550
# 27600
# 27650
# 27700
# 27750
# 27800
# 27850
# 27900
# 27950
# 28000
# 28050
# 28100
# 28150
# 28200
# 28250
# 28300
# 28350
# 28400
# 28450
# 28500
# 28550
# 28600
# 28650
# 28700
# 28750
# 28800
# 28850
# 28900
# 28950
# 29000
# 29050
# 29100
# 29150
# 29200
# 29250
# 29300
# 29350
# 29400
# 29450
# 29500
# 29550
# 29600
# 29650
# 29700
# 29750
# 29800
# 29850
# 29900
# 29950
# 30000
# 30050
# 30100
# 30150
# 30200
# 30250
# 30300
# 30350
# 30400
# 30450
# 30500
# 30550
# 30600
# 30650
# 30700
# 30750
# 30800
# 30850
# 30900
# 30950
# 31000
# 31050
# 31100
# 31150
# 31200
# 31250
# 31300
# 31350
# 31400
# 31450
# 31500
# 31550
# 31600
# 31650
# 31700
# 31750
# 31800
# 31850
# 31900
# 31950
# 32000
# 32050
# 32100
# 32150
# 32200
# 32250
# 32300
# 32350
# 32400
# 32450
# 32500
# 32550
# 32600
# 32650
# 32700
# 32750
# 32800
# 32850
# 32900
# 32950
# 33000
# 33050
# 33100
# 33150
# 33200
# 33250
# 33300
# 33350
# 33400
# 33450
# 33500
# 33550
# 33600
# 33650
# 33700
# 33750
# 33800
# 33850
# 33900
# 33950
# 34000
# 34050
# 34100
# 34150
# 34200
# 34250
# 34300
# 34350
# 34400
# 34450
# 34500
# 34550
# 34600
# 34650
# 34700
# 34750
# 34800
# 34850
# 34900
# 34950
# 35000
# 35050
# 35100
# 35150
# 35200
# 35250
# 35300
# 35350
# 35400
# 35450
# 35500
# 35550
# 35600
# 35650
# 35700
# 35750
# 35800
# 35850
# 35900
# 35950
# 36000
# 36050
# 36100
# 36150
# 36200
# 36250
# 36300
# 36350
# 36400
# 36450
# 36500
# 36550
# 36600
# 36650
# 36700
# 36750
# 36800
# 36850
# 36900
# 36950
# 37000
# 37050
# 37100
# 37150
# 37200
# 37250
# 37300
# 37350
# 37400
# 37450
# 37500
# 37550
# 37600
# 37650
# 37700
# 37750
# 37800
# 37850
# 37900
# 37950
# 38000
# 38050
# 38100
# 38150
# 38200
# 38250
# 38300
# 38350
# 38400
# 38450
# 38500
# 38550
# 38600
# 38650
# 38700
# 38750
# 38800
# 38850
# 38900
# 38950
# 39000
# 39050
# 39100
# 39150
# 39200
# 39250
# 39300
# 39350
# 39400
# 39450
# 39500
# 39550
# 39600
# 39650
# 39700
# 39750
# 39800
# 39850
# 39900
# 39950
# 40000
# 40050
# 40100
# 40150
# 40200
# 40250
# 40300
# 40350
# 40400
# 40450
# 40500
# 40550
# 40600
# 40650
# 40700
# 40750
# 40800
# 40850
# 40900
# 40950
# 41000
# 41050
# 41100
# 41150
# 41200
# 41250
# 41300
# 41350
# 41400
# 41450
# 41500
# 41550
# 41600
# 41650
# 41700
# 41750
# 41800
# 41850
# 41900
# 41950
# 42000
# 42050
# 42100
# 42150
# 42200
# 42250
# 42300
# 42350
# 42400
# 42450
# 42500
# 42550
# 42600
# 42650
# 42700
# 42750
# 42800
# 42850
# 42900
# 42950
# 43000
# 43050
# 43100
# 43150
# 43200
# 43250
# 43300
# 43350
# 43400
# 43450
# 43500
# 43550
# 43600
# 43650
# 43700
# 43750
# 43800
# 43850
# 43900
# 43950
# 44000
# 44050
# 44100
# 44150
# 44200
# 44250
# 44300
# 44350
# 44400
# 44450
# 44500
# 44550
# 44600
# 44650
# 44700
# 44750
# 44800
# 44850
# 44900
# 44950
# 45000
# 45050
# 45100
# 45150
# 45200
# 45250
# 45300
# 45350
# 45400
# 45450
# 45500
# 45550
# 45600
# 45650
# 45700
# 45750
# 45800
# 45850
# 45900
# 45950
# 46000
# 46050
# 46100
# 46150
# 46200
# 46250
# 46300
# 46350
# 46400
# 46450
# 46500
# 46550
# 46600
# 46650
# 46700
# 46750
# 46800
# 46850
# 46900
# 46950
# 47000
# 47050
# 47100
# 47150
# 47200
# 47250
# 47300
# 47350
# 47400
# 47450
# 47500
# 47550
# 47600
# 47650
# 47700
# 47750
# 47800
# 47850
# 47900
# 47950
# 48000
# 48050
# 48100
# 48150
# 48200
# 48250
# 48300
# 48350
# 48400
# 48450
# 48500
# 48550
# 48600
# 48650
# 48700
# 48750
# 48800
# 48850
# 48900
# 48950
# 49000
# 49050
# 49100
# 49150
# 49200
# 49250
# 49300
# 49350
# 49400
# 49450
# 49500
# 49550
# 49600
# 49650
# 49700
# 49750
# 49800
# 49850
# 49900
# 49950
# 50000
# 50050
# 50100
# 50150
# 50200
# 50250
# 50300
# 50350
# 50400
# 50450
# 50500
# 50550
# 50600
# 50650
# 50700
# 50750
# 50800
# 50850
# 50900
# 50950
# 51000
# 51050
# 51100
# 51150
# 51200
# 51250
# 51300
# 51350
# 51400
# 51450
# 51500
# 51550
# 51600
# 51650
# 51700
# 51750
# 51800
# 51850
# 51900
# 51950
# 52000
# 52050
# 52100
# 52150
# 52200
# 52250
# 52300
# 52350
# 52400
# 52450
# 52500
# 52550
# 52600
# 52650
# 52700
# 52750
# 52800
# 52850
# 52900
# 52950
# 53000
# 53050
# 53100
# 53150
# 53200
# 53250
# 53300
# 53350
# 53400
# 53450
# 53500
# 53550
# 53600
# 53650
# 53700
# 53750
# 53800
# 53850
# 53900
# 53950
# 54000
# 54050
# 54100
# 54150
# 54200
# 54250
# 54300
# 54350
# 54400
# 54450
# 54500
# 54550
# 54600
# 54650
# 54700
# 54750
# 54800
# 54850
# 54900
# 54950
# 55000
# 55050
# 55100
# 55150
# 55200
# 55250
# 55300
# 55350
# 55400
# 55450
# 55500
# 55550
# 55600
# 55650
# 55700
# 55750
# 55800
# 55850
# 55900
# 55950
# 56000
# 56050
# 56100
# 56150
# 56200
# 56250
# 56300
# 56350
# 56400
# 56450
# 56500
# 56550
# 56600
# 56650
# 56700
# 56750
# 56800
# 56850
# 56900
# 56950
# 57000
# 57050
# 57100
# 57150
# 57200
# 57250
# 57300
# 57350
# 57400
# 57450
# 57500
# 57550
# 57600
# 57650
# 57700
# 57750
# 57800
# 57850
# 57900
# 57950
# 58000
# 58050
# 58100
# 58150
# 58200
# 58250
# 58300
# 58350
# 58400
# 58450
# 58500
# 58550
# 58600
# 58650
# 58700
# 58750
# 58800
# 58850
# 58900
# 58950
# 59000
# 59050
# 59100
# 59150
# 59200
# 59250
# 59300
# 59350
# 59400
# 59450
# 59500
# 59550
# 59600
# 59650
# 59700
# 59750
# 59800
# 59850
# 59900
# 59950
# 60000
# 60050
# 60100
# 60150
# 60200
# 60250
# 60300
# 60350
# 60400
# 60450
# 60500
# 60550
# 60600
# 60650
# 60700
# 60750
# 60800
# 60850
# 60900
# 60950
# 61000
# 61050
# 61100
# 61150
# 61200
# 61250
# 61300
# 61350
# 61400
# 61450
# 61500
# 61550
# 61600
# 61650
# 61700
# 61750
# 61800
# 61850
# 61900

# %%
amazon_ebooks_metadata = pd.read_csv(amazon_aws_ebooks).rename(columns={'Unnamed: 0':'asin'}).drop_duplicates(subset='asin')
amazon_ebooks_metadata['title'] = amazon_ebooks_metadata.title.str.lower()
amazon_ebooks_metadata['authors'] = amazon_ebooks_metadata.authors.str.lower()
#amazon_ebooks_metadata['title'] = amazon_ebooks_metadata['title'].str.replace(r"\(.*\)|\[.*\]","")

# %%
amazon_ebooks_metadata = amazon_ebooks_metadata.dropna(subset=['authors'])
amazon_ebooks_metadata_multiple_authors = amazon_ebooks_metadata[amazon_ebooks_metadata.authors.str.contains(',')]

# %%
authors = amazon_ebooks_metadata_multiple_authors.authors.str.split(',')
count = 0

new_df = pd.DataFrame(columns=['asin', 'title', 'authors', 'manufacturer'])

for i,(index, row) in enumerate(amazon_ebooks_metadata_multiple_authors.iterrows()):
    for author in authors.iloc[i]:
        new_df.loc[count] = row
        new_df.loc[count].authors = author
        count += 1
new_df
# Out:
#             asin                                              title  \
# 0     B000FA64PA  saboteur: star wars legends (darth maul) (shor...
# 1     B000FA64PA  saboteur: star wars legends (darth maul) (shor...
# 2     B000FA64PA  saboteur: star wars legends (darth maul) (shor...
# 3     B000FA64PA  saboteur: star wars legends (darth maul) (shor...
# 4     B000FA64PA  saboteur: star wars legends (darth maul) (shor...
# 5     B000FA64PK  recovery: star wars legends (the new jedi orde...
# 6     B000FA64PK  recovery: star wars legends (the new jedi orde...
# 7     B000FA64PK  recovery: star wars legends (the new jedi orde...
# 8     B000FA64PK  recovery: star wars legends (the new jedi orde...
# 9     B000FA64PK  recovery: star wars legends (the new jedi orde...
# 10    B000PDZG6K                                          tallchief
# 11    B000PDZG6K                                          tallchief
# 12    B001AWYAZ8  the life of a child survivor from bialystok, p...
# 13    B001AWYAZ8  the life of a child survivor from bialystok, p...
# 14    B001AWYAZ8  the life of a child survivor from bialystok, p...
# 15    B001EWEB5I  an autobiography: the story of my experiments ...
# 16    B001EWEB5I  an autobiography: the story of my experiments ...
# 17    B001TK41W8                         from the cell to the cross
# 18    B001TK41W8                         from the cell to the cross
# 19    B001VH6NWU  reality creation 101: mastering manifestation ...
# 20    B001VH6NWU  reality creation 101: mastering manifestation ...
# 21    B001VH6NWU  reality creation 101: mastering manifestation ...
# 22    B001VH6NWU  reality creation 101: mastering manifestation ...
# 23    B001VH6NWU  reality creation 101: mastering manifestation ...
# 24    B00200JXAG                                  campaign for love
# 25    B00200JXAG                                  campaign for love
# 26    B00264H2VI  65 proof - jack daniels and other thriller sto...
# 27    B00264H2VI  65 proof - jack daniels and other thriller sto...
# 28    B0026ZOJ18        the christian novel collection (four books)
# 29    B0026ZOJ18        the christian novel collection (four books)
# ...          ...                                                ...
# 6022  B00LQB1IIU                   body games (games series book 5)
# 6023  B00LQTGPWG               inferno: a devil chaser's mc romance
# 6024  B00LQTGPWG               inferno: a devil chaser's mc romance
# 6025  B00LRSN11Y                       ricochet (renegades, book 3)
# 6026  B00LRSN11Y                       ricochet (renegades, book 3)
# 6027  B00LS153XO  summer in new york collection (a timeless roma...
# 6028  B00LS153XO  summer in new york collection (a timeless roma...
# 6029  B00LS153XO  summer in new york collection (a timeless roma...
# 6030  B00LS153XO  summer in new york collection (a timeless roma...
# 6031  B00LS153XO  summer in new york collection (a timeless roma...
# 6032  B00LS153XO  summer in new york collection (a timeless roma...
# 6033  B00LS6MCMY     leather and lace (lonesome point texas book 1)
# 6034  B00LS6MCMY     leather and lace (lonesome point texas book 1)
# 6035  B00LT48ZR6  touched by the dark: a paranormal romance (imm...
# 6036  B00LT48ZR6  touched by the dark: a paranormal romance (imm...
# 6037  B00LTATG9G  diabetes cure: my against all odds story of ho...
# 6038  B00LTATG9G  diabetes cure: my against all odds story of ho...
# 6039  B00LTATG9G  diabetes cure: my against all odds story of ho...
# 6040  B00LU6N5UU    into the shadows (undercover associates book 3)
# 6041  B00LU6N5UU    into the shadows (undercover associates book 3)
# 6042  B00LVBJOYK                                          hourglass
# 6043  B00LVBJOYK                                          hourglass
# 6044  B00LWRN8SQ                               the name on her lips
# 6045  B00LWRN8SQ                               the name on her lips
# 6046  B00LWSNUQ0                           thrive (addicted series)
# 6047  B00LWSNUQ0                           thrive (addicted series)
# 6048  B00LXQIL06  alpha's last fight: a paranormal shapeshifter ...
# 6049  B00LXQIL06  alpha's last fight: a paranormal shapeshifter ...
# 6050  B00M0RE7CS                                           packaged
# 6051  B00M0RE7CS                                           packaged
#
#                       authors                              manufacturer
# 0                james luceno                                   Del Rey
# 1                    ron marz                                   Del Rey
# 2                jan duursema                                   Del Rey
# 3                 rick magyar                                   Del Rey
# 4                drew struzan                                   Del Rey
# 5                troy denning                                   Del Rey
# 6                    ron marz                                   Del Rey
# 7                jan duursema                                   Del Rey
# 8                 rick magyar                                   Del Rey
# 9                drew struzan                                   Del Rey
# 10               dinah mccall                     HarperCollins e-books
# 11                sharon sala                     HarperCollins e-books
# 12                 ben midler                                      self
# 13        ellen midler winter                                      self
# 14                gavin stein                                      self
# 15         mohandas k. gandhi                         Formax Publishing
# 16              mahadev desai                         Formax Publishing
# 17                 don dennis                     Reflection Publishing
# 18           shirley stephens                     Reflection Publishing
# 19    christopher a. pinckley                       RedBrick Publishing
# 20                  lisa zure                       RedBrick Publishing
# 21             brad yates cht                       RedBrick Publishing
# 22                  lisa zure                       RedBrick Publishing
# 23             cht brad yates                       RedBrick Publishing
# 24          annabelle stevens  HerStory Books, http://herstorybooks.com
# 25         sorcha macmurrough  HerStory Books, http://herstorybooks.com
# 26               j.a. konrath                                       NaN
# 27               jack kilborn                                       NaN
# 28                    various                          Douglas Editions
# 29       greatest hits series                          Douglas Editions
# ...                       ...                                       ...
# 6022               jill myles                                Jill Myles
# 6023                l. wilder                                       NaN
# 6024             brooke asher                                       NaN
# 6025              skye jordan                              Cygnet Books
# 6026                joan swan                              Cygnet Books
# 6027         janette rallison                              Mirror Press
# 6028         heather b. moore                              Mirror Press
# 6029            luisa perkins                              Mirror Press
# 6030            sarah m. eden                              Mirror Press
# 6031             annette lyon                              Mirror Press
# 6032              lisa mangum                              Mirror Press
# 6033             lili valente                   Self Taught Ninja Press
# 6034             jessie evans                   Self Taught Ninja Press
# 6035               lj swallow                                       NaN
# 6036             lisa swallow                                       NaN
# 6037          jessica brennan                            Talent Writers
# 6038            william black                            Talent Writers
# 6039            tiffany banks                            Talent Writers
# 6040            carolyn crane                                       NaN
# 6041            annika martin                                       NaN
# 6042               k.s. smith                     Blue Tulip Publishing
# 6043           megan c. smith                     Blue Tulip Publishing
# 6044           maria diamante                       Epic Dreams Erotica
# 6045            john rowlands                       Epic Dreams Erotica
# 6046           krista ritchie                              K.B. Ritchie
# 6047            becca ritchie                              K.B. Ritchie
# 6048              aubrey rose                                       NaN
# 6049             molly prince                                       NaN
# 6050            angela graham                                       NaN
# 6051                s.e. hall                                       NaN
#
# [6052 rows x 4 columns]

# %%
amazon_ebooks_metadata = pd.concat([amazon_ebooks_metadata, new_df])

# %%
amazon_ebooks_metadata
# Out:
#             asin                                              title  \
# 0     B000F83SZQ       a matter of policy [an amy brewster mystery]
# 1     B000FA64PA  saboteur: star wars legends (darth maul) (shor...
# 2     B000FA64PK  recovery: star wars legends (the new jedi orde...
# 3     B000FA64QO  ylesia: star wars legends (the new jedi order)...
# 4     B000FBFMVG  a forest apart: star wars legends (short story...
# 5     B000FC1BN8  fool's bargain: star wars legends (novella) (s...
# 6     B000FC1TG2                                   the iron marshal
# 7     B000FC2MB8                                   brionne: a novel
# 8     B000JMKNQ0  boba fett: a practical man: star wars legends ...
# 9     B000JMLBHU                              the mysterious island
# 10    B000JMLG4S  knots, splices and rope work a practical treatise
# 11    B000JMLHYC                                the english orphans
# 12    B000JQUSBQ                                 indian fairy tales
# 13    B000JQUT8S                                       oliver twist
# 14    B000JQUTGK  the lincoln story book a judicious collection ...
# 15    B000JQUU00                                english fairy tales
# 16    B000JQUXBQ  the diary of a u-boat commanderwith an introdu...
# 17    B000MAH6G4                       hawke: the law of a fast gun
# 18    B000MAH73Q     falling in love again (avon romantic treasure)
# 19    B000NY11RY                       tempt me, taste me, touch me
# 20    B000PDZG6K                                          tallchief
# 21    B000Q9J0CO  caught off guard [heroes of silver springs 1] ...
# 22    B000QCS8YM  sherlock holmes: the complete novels and stori...
# 23    B000QUCOB2          stealing sophie (avon historical romance)
# 24    B000R3NNAE                           hawke: the king hill war
# 25    B000SEGE3K                       sky hunters: anarchy's reign
# 26    B000SN6IOQ                                   allan quatermain
# 27    B000TU16PE                 the highland rogues: warrior bride
# 28    B000U0NSV8          an unladylike offer (the radwells book 2)
# 29    B000UB9NCK                                       the stranger
# ...          ...                                                ...
# 6022  B00LQB1IIU                   body games (games series book 5)
# 6023  B00LQTGPWG               inferno: a devil chaser's mc romance
# 6024  B00LQTGPWG               inferno: a devil chaser's mc romance
# 6025  B00LRSN11Y                       ricochet (renegades, book 3)
# 6026  B00LRSN11Y                       ricochet (renegades, book 3)
# 6027  B00LS153XO  summer in new york collection (a timeless roma...
# 6028  B00LS153XO  summer in new york collection (a timeless roma...
# 6029  B00LS153XO  summer in new york collection (a timeless roma...
# 6030  B00LS153XO  summer in new york collection (a timeless roma...
# 6031  B00LS153XO  summer in new york collection (a timeless roma...
# 6032  B00LS153XO  summer in new york collection (a timeless roma...
# 6033  B00LS6MCMY     leather and lace (lonesome point texas book 1)
# 6034  B00LS6MCMY     leather and lace (lonesome point texas book 1)
# 6035  B00LT48ZR6  touched by the dark: a paranormal romance (imm...
# 6036  B00LT48ZR6  touched by the dark: a paranormal romance (imm...
# 6037  B00LTATG9G  diabetes cure: my against all odds story of ho...
# 6038  B00LTATG9G  diabetes cure: my against all odds story of ho...
# 6039  B00LTATG9G  diabetes cure: my against all odds story of ho...
# 6040  B00LU6N5UU    into the shadows (undercover associates book 3)
# 6041  B00LU6N5UU    into the shadows (undercover associates book 3)
# 6042  B00LVBJOYK                                          hourglass
# 6043  B00LVBJOYK                                          hourglass
# 6044  B00LWRN8SQ                               the name on her lips
# 6045  B00LWRN8SQ                               the name on her lips
# 6046  B00LWSNUQ0                           thrive (addicted series)
# 6047  B00LWSNUQ0                           thrive (addicted series)
# 6048  B00LXQIL06  alpha's last fight: a paranormal shapeshifter ...
# 6049  B00LXQIL06  alpha's last fight: a paranormal shapeshifter ...
# 6050  B00M0RE7CS                                           packaged
# 6051  B00M0RE7CS                                           packaged
#
#                                                 authors  \
# 0                                        sam merwin jr.
# 1     james luceno, ron marz, jan duursema, rick mag...
# 2     troy denning, ron marz, jan duursema, rick mag...
# 3                                   walter jon williams
# 4                                          troy denning
# 5                                          timothy zahn
# 6                                         louis l'amour
# 7                                         louis l'amour
# 8                                         karen traviss
# 9                                           jules verne
# 10                            a.(alpheus) hyatt verrill
# 11                                     mary jane holmes
# 12                                  public domain books
# 13                                      charles dickens
# 14                             henry llewellyn williams
# 15                                        joseph jacobs
# 16                                  public domain books
# 17                                       robert vaughan
# 18                                        cathy maxwell
# 19                                          bella andre
# 20                            dinah mccall, sharon sala
# 21                                        tonya ramagos
# 22                                   arthur conan doyle
# 23                                        sarah gabriel
# 24                                       robert vaughan
# 25                                           jack shane
# 26                       h. rider (henry rider) haggard
# 27                                         lois greiman
# 28                                    christine merrill
# 29                                       elizabeth lane
# ...                                                 ...
# 6022                                         jill myles
# 6023                                          l. wilder
# 6024                                       brooke asher
# 6025                                        skye jordan
# 6026                                          joan swan
# 6027                                   janette rallison
# 6028                                   heather b. moore
# 6029                                      luisa perkins
# 6030                                      sarah m. eden
# 6031                                       annette lyon
# 6032                                        lisa mangum
# 6033                                       lili valente
# 6034                                       jessie evans
# 6035                                         lj swallow
# 6036                                       lisa swallow
# 6037                                    jessica brennan
# 6038                                      william black
# 6039                                      tiffany banks
# 6040                                      carolyn crane
# 6041                                      annika martin
# 6042                                         k.s. smith
# 6043                                     megan c. smith
# 6044                                     maria diamante
# 6045                                      john rowlands
# 6046                                     krista ritchie
# 6047                                      becca ritchie
# 6048                                        aubrey rose
# 6049                                       molly prince
# 6050                                      angela graham
# 6051                                          s.e. hall
#
#                  manufacturer
# 0                  PageTurner
# 1                     Del Rey
# 2                     Del Rey
# 3                     Del Rey
# 4                     Del Rey
# 5                     Del Rey
# 6                      Bantam
# 7                      Bantam
# 8                     Del Rey
# 9         Public Domain Books
# 10        Public Domain Books
# 11        Public Domain Books
# 12        Public Domain Books
# 13        Public Domain Books
# 14        Public Domain Books
# 15        Public Domain Books
# 16        Public Domain Books
# 17      HarperCollins e-books
# 18      HarperCollins e-books
# 19               Pocket Books
# 20      HarperCollins e-books
# 21           Siren Publishing
# 22            Bantam Classics
# 23      HarperCollins e-books
# 24      HarperCollins e-books
# 25      HarperCollins e-books
# 26        Public Domain Books
# 27      HarperCollins e-books
# 28       Harlequin Historical
# 29       Harlequin Historical
# ...                       ...
# 6022               Jill Myles
# 6023                      NaN
# 6024                      NaN
# 6025             Cygnet Books
# 6026             Cygnet Books
# 6027             Mirror Press
# 6028             Mirror Press
# 6029             Mirror Press
# 6030             Mirror Press
# 6031             Mirror Press
# 6032             Mirror Press
# 6033  Self Taught Ninja Press
# 6034  Self Taught Ninja Press
# 6035                      NaN
# 6036                      NaN
# 6037           Talent Writers
# 6038           Talent Writers
# 6039           Talent Writers
# 6040                      NaN
# 6041                      NaN
# 6042    Blue Tulip Publishing
# 6043    Blue Tulip Publishing
# 6044      Epic Dreams Erotica
# 6045      Epic Dreams Erotica
# 6046             K.B. Ritchie
# 6047             K.B. Ritchie
# 6048                      NaN
# 6049                      NaN
# 6050                      NaN
# 6051                      NaN
#
# [55134 rows x 4 columns]

# %%
amazon_books_metadata_yves = pd.read_csv(amazon_aws_books_yves, encoding = "latin1").rename(columns={'Unnamed: 0':'asin'}).drop_duplicates(subset='asin')
amazon_books_metadata_yves['title'] = amazon_books_metadata_yves.title.str.lower()
amazon_books_metadata_yves['authors'] = amazon_books_metadata_yves.authors.str.lower()
#amazon_books_metadata_yves['title'] = amazon_books_metadata_yves['title'].str.replace(r"\(.*\)|\[.*\]","")
amazon_books_metadata_yves = amazon_books_metadata_yves.dropna(subset=['authors'])
amazon_books_metadata_yves_multiple_authors = amazon_books_metadata_yves[amazon_books_metadata_yves.authors.str.contains(',')]

authors = amazon_books_metadata_yves_multiple_authors.authors.str.split(',')
count = 0

new_df = pd.DataFrame(columns=['asin', 'title', 'authors', 'manufacturer'])

for i,(index, row) in enumerate(amazon_books_metadata_yves_multiple_authors.iterrows()):
    for author in authors.iloc[i]:
        new_df.loc[count] = row
        new_df.loc[count].authors = author
        count += 1
new_df

amazon_books_metadata_yves = pd.concat([amazon_books_metadata_yves, new_df])

merged_amazon = amazon_books_metadata_yves.merge(amazon_ebooks_metadata, left_on='title', right_on='title').rename(columns={'asin_x':'asin_books', 'asin_y':'asin_ebooks'})
merged_amazon_prime = merged_amazon[merged_amazon.authors_x == merged_amazon.authors_y]
merged_amazon_prime
# Out:
#       asin_books                                              title  \
# 93    0060813032  dragons from the sea (the strongbow saga, book 2)
# 221   0061659282                  untamed city: carnival of secrets
# 380   0140287957                                   an ideal husband
# 381   0140364749                                         lad: a dog
# 396   0141196882                                            dracula
# 510   0307266931                                      war and peace
# 761   0345548957                     a wedding in provence: a novel
# 907   0380486032                                            rebecca
# 1038  0393096696                              the turn of the screw
# 1106  0425147770                            whispers from the grave
# 1191  0440134986                                  a heart too proud
# 1240  0446363049                                             vortex
# 1244  0446363049                                             vortex
# 1248  0446363049                                             vortex
# 1338  0451191137                                             anthem
# 1345  0451202821                                her daughter's eyes
#
#                        authors_x       manufacturer_x asin_ebooks  \
# 93                judson roberts           HarperTeen  B0049H8X86
# 221                 melissa marr           HarperColl  B007HBY0VK
# 380                  oscar wilde        Penguin Books  B004UJCKQY
# 381        albert payson terhune         Puffin Books  B0076QWBD0
# 396                  bram stoker     Penguin Classics  B00J69Y3PY
# 510                  leo tolstoy                Knopf  B003X4M9F4
# 761                ellen sussman     Ballantine Books  B00I1ZG5HI
# 907            daphne du maurier           Avon Books  B00CO7FLJM
# 1038                 henry james  W W Norton & Co Inc  B004UJIUD6
# 1106                 leslie rule              Berkley  B00C6QQBZO
# 1191                laura london                 Dell  B00CO7GGSM
# 1240  larry bond, patrick larkin   Warner Books, Inc.  B008OM2BHQ
# 1244                  larry bond   Warner Books, Inc.  B008OM2BHQ
# 1248              patrick larkin   Warner Books, Inc.  B008OM2BHQ
# 1338                    ayn rand               Signet  B0082RHM4A
# 1345    jessica barksdale inclan            NAL Trade  B0051ZN10A
#
#                        authors_y                  manufacturer_y
# 93                judson roberts                  Northman Books
# 221                 melissa marr                   HarperCollins
# 380                  oscar wilde                             NaN
# 381        albert payson terhune                             NaN
# 396                  bram stoker                Simon & Schuster
# 510                  leo tolstoy  Superior Formatting Publishing
# 761                ellen sussman                Ballantine Books
# 907            daphne du maurier       Little, Brown and Company
# 1038                 henry james                             NaN
# 1106                 leslie rule            Planet Ann Rule, LLC
# 1191                laura london                   Forever Yours
# 1240  larry bond, patrick larkin                             NaN
# 1244                  larry bond                             NaN
# 1248              patrick larkin                             NaN
# 1338                    ayn rand                             NaN
# 1345    jessica barksdale inclan                             NaN

# %%
merged_amazon_prime.shape
# Out:
# (16, 7)

# %%
amazon_books_metadata_pa = pd.read_csv(amazon_aws_books_pa).rename(columns={'Unnamed: 0':'asin'}).drop_duplicates(subset='asin')
amazon_books_metadata_pa['title'] = amazon_books_metadata_pa.title.str.lower()
amazon_books_metadata_pa['authors'] = amazon_books_metadata_pa.authors.str.lower()
#amazon_books_metadata_pa['title'] = amazon_books_metadata_pa['title'].str.replace(r"\(.*\)|\[.*\]","")
amazon_books_metadata_pa = amazon_books_metadata_pa.dropna(subset=['authors'])
amazon_books_metadata_pa_multiple_authors = amazon_books_metadata_pa[amazon_books_metadata_pa.authors.str.contains(',')]

authors = amazon_books_metadata_pa_multiple_authors.authors.str.split(',')
count = 0

new_df = pd.DataFrame(columns=['asin', 'title', 'authors', 'manufacturer'])

for i,(index, row) in enumerate(amazon_books_metadata_pa_multiple_authors.iterrows()):
    for author in authors.iloc[i]:
        new_df.loc[count] = row
        new_df.loc[count].authors = author
        count += 1
new_df

amazon_books_metadata_pa = pd.concat([amazon_books_metadata_pa, new_df])




merged_amazon = amazon_books_metadata_pa.merge(amazon_ebooks_metadata, left_on='title', right_on='title').rename(columns={'asin_x':'asin_books', 'asin_y':'asin_ebooks'})
merged_amazon_prime = merged_amazon[merged_amazon.authors_x == merged_amazon.authors_y]
merged_amazon_prime
# Out:
#      asin_books                                 title               authors_x  \
# 89   0679642366                 the mysterious island             jules verne
# 147  0735822271                                 heidi           johanna spyri
# 337  0758242212                     sweet little lies           michele grant
# 399  0760712727  benedict arnold: patriot and traitor  willard sterne randall
# 525  0786010924                      all the way home       wendy corsi staub
# 526  0786011327                              moonfall           tamara thorne
# 663  0843946237                        beyond forever              debra dier
# 680  084395261X                            open range            lauran paine
# 688  0843959142                             star born            andre norton
# 710  087004124X                                anthem                ayn rand
#
#             manufacturer_x asin_ebooks               authors_y  \
# 89          Modern Library  B000JMLBHU             jules verne
# 147       NorthSouth Books  B004TPPYJY           johanna spyri
# 337                 Dafina  B00DZURKXC           michele grant
# 399           Dorset Press  B0083UL1F2  willard sterne randall
# 525               Pinnacle  B009NQZY1C       wendy corsi staub
# 526               Pinnacle  B009TZRUKK           tamara thorne
# 663          Leisure Books  B00HDEEKJS              debra dier
# 680  Dorchester Pub Co Inc  B009NXLYIM            lauran paine
# 688                 Cosmos  B004TPG9ZM            andre norton
# 710           Caxton Press  B0082RHM4A                ayn rand
#
#           manufacturer_y
# 89   Public Domain Books
# 147                  NaN
# 337               Dafina
# 399  New Word City, Inc.
# 525               Harper
# 526        Tamara Thorne
# 663     Dierington Press
# 680         AmazonEncore
# 688                  NaN
# 710                  NaN

# %%
merged_amazon_prime.shape
# Out:
# (10, 7)

# %%
#pd.merge(amazon_ebooks_metadata.title.str.lower(), books_metadata.title.str.lower())
books_metadata.merge(amazon_ebooks_metadata, left_on='title', right_on='title').rename(columns={'asin_x':'asin_books', 'asin_y':'asin_ebooks'})
# Out:
#        Unnamed: 0  asin_books            salesRank   categories  \
# 0             145  0001981692  {'Books': 11831050}  [['Books']]
# 1          451645  0671873164   {'Books': 1117160}  [['Books']]
# 2          820435  088388027X   {'Books': 1863186}  [['Books']]
# 3         1087185  1416927344    {'Books': 248278}  [['Books']]
# 4         1309521  1558594051  {'Books': 10853889}  [['Books']]
# 5         1421569  1590784553    {'Books': 993678}  [['Books']]
# 6         1494164  1606591827   {'Books': 2569651}  [['Books']]
# 7         1779659  B0002MJDKO   {'Books': 7990596}  [['Books']]
# 8             172  0002008211   {'Books': 5219330}  [['Books']]
# 9          126720  0263743608   {'Books': 5898534}  [['Books']]
# 10         187182  033045157X   {'Books': 1071929}  [['Books']]
# 11         597731  0778328015   {'Books': 1218056}  [['Books']]
# 12         611314  0786010908   {'Books': 2167685}  [['Books']]
# 13         611493  0786016841    {'Books': 602214}  [['Books']]
# 14         900588  0956410170                  NaN  [['Books']]
# 15         946070  0972716025   {'Books': 2838504}  [['Books']]
# 16        1012514  0986556904   {'Books': 7501299}  [['Books']]
# 17        1204528  1466225890  {'Books': 10108097}  [['Books']]
# 18        1277102  1494469308                  NaN  [['Books']]
# 19        1285883  1499311877   {'Books': 2162014}  [['Books']]
# 20        1544369  1783336285   {'Books': 2696259}  [['Books']]
# 21        1634483  1897299265   {'Books': 2507766}  [['Books']]
# 22        1759072  938015495X   {'Books': 3599478}  [['Books']]
# 23            270  0002008505   {'Books': 5587764}  [['Books']]
# 24         426833  0615891411   {'Books': 4145053}  [['Books']]
# 25        1380542  1579660584   {'Books': 2486827}  [['Books']]
# 26        1412333  1588515508   {'Books': 5985767}  [['Books']]
# 27        1448217  1595143394    {'Books': 141638}  [['Books']]
# 28        1477494  1601540817  {'Books': 11114107}  [['Books']]
# 29        1532498  1625530226   {'Books': 2678708}  [['Books']]
# ...           ...         ...                  ...          ...
# 13178     1846370  B000TFTIC2   {'Books': 8889086}  [['Books']]
# 13179     1847316  B000U44BIS   {'Books': 1103192}  [['Books']]
# 13180     1847708  B000UDPEYY                  NaN  [['Books']]
# 13181     1872509  B001JCVIGS                  NaN  [['Books']]
# 13182     1847860  B000UEYYE4  {'Books': 10273803}  [['Books']]
# 13183     1852063  B000X00RNC   {'Books': 6990961}  [['Books']]
# 13184     1856506  B0011MRGLC   {'Books': 7813520}  [['Books']]
# 13185     1863372  B0018E04JE    {'Books': 384423}  [['Books']]
# 13186     1872060  B001ISOBLC   {'Books': 6393218}  [['Books']]
# 13187     1872898  B001JYTR32                  NaN  [['Books']]
# 13188     1874342  B001LOMPP2   {'Books': 4414963}  [['Books']]
# 13189     1878431  B001QXC4O0   {'Books': 2717429}  [['Books']]
# 13190     1883816  B0024QTCDO                  NaN  [['Books']]
# 13191     1884156  B00262OJUM   {'Books': 8475458}  [['Books']]
# 13192     1884160  B00262O8ZI  {'Books': 10932845}  [['Books']]
# 13193     1887443  B002AJGLO8   {'Books': 4014766}  [['Books']]
# 13194     1887479  B002ALUAJS   {'Books': 3624486}  [['Books']]
# 13195     1929330  B0043NZKKU   {'Books': 3831799}  [['Books']]
# 13196     1893680  B002KYF3SS   {'Books': 2386450}  [['Books']]
# 13197     1895438  B002OBTPXQ    {'Books': 491310}  [['Books']]
# 13198     1897893  B002SR8KTG   {'Books': 6629752}  [['Books']]
# 13199     1911315  B003F20PSM  {'Books': 10132076}  [['Books']]
# 13200     1919643  B003UILUJ4    {'Books': 544107}  [['Books']]
# 13201     1926161  B0040V4H9U   {'Books': 9739966}  [['Books']]
# 13202     1974255  B0052VHMEE   {'Books': 4965839}  [['Books']]
# 13203     1996530  B005LE4RMC   {'Books': 8580459}  [['Books']]
# 13204     2024317  B006ONEE0E   {'Books': 3003064}  [['Books']]
# 13205     2046520  B007EPSQW8                  NaN  [['Books']]
# 13206     2060207  B007SD1BBY   {'Books': 4335299}  [['Books']]
# 13207     2272336  B00FLBQ11A   {'Books': 1284224}  [['Books']]
#
#                                                    title  price asin_ebooks  \
# 0                                                pirates    NaN  B00K0SCMYO
# 1                                                pirates   7.59  B00K0SCMYO
# 2                                                pirates   5.35  B00K0SCMYO
# 3                                                pirates  15.61  B00K0SCMYO
# 4                                                pirates    NaN  B00K0SCMYO
# 5                                                pirates  13.96  B00K0SCMYO
# 6                                                pirates   4.99  B00K0SCMYO
# 7                                                pirates   6.29  B00K0SCMYO
# 8                                                haunted    NaN  B005Z53TA8
# 9                                                haunted    NaN  B005Z53TA8
# 10                                               haunted   6.15  B005Z53TA8
# 11                                               haunted   5.54  B005Z53TA8
# 12                                               haunted   4.49  B005Z53TA8
# 13                                               haunted   4.49  B005Z53TA8
# 14                                               haunted   2.99  B005Z53TA8
# 15                                               haunted  24.36  B005Z53TA8
# 16                                               haunted   6.92  B005Z53TA8
# 17                                               haunted   2.99  B005Z53TA8
# 18                                               haunted   3.99  B005Z53TA8
# 19                                               haunted   0.99  B005Z53TA8
# 20                                               haunted   4.99  B005Z53TA8
# 21                                               haunted  21.78  B005Z53TA8
# 22                                               haunted  13.67  B005Z53TA8
# 23                                     the space between   4.74  B002DYJ7DM
# 24                                     the space between   2.99  B002DYJ7DM
# 25                                     the space between  20.08  B002DYJ7DM
# 26                                     the space between    NaN  B002DYJ7DM
# 27                                     the space between   7.13  B002DYJ7DM
# 28                                     the space between  10.99  B002DYJ7DM
# 29                                     the space between   6.99  B002DYJ7DM
# ...                                                  ...    ...         ...
# 13178                                  the king's choice    NaN  B0041VXCWC
# 13179                                          i believe    NaN  B006GTTM58
# 13180                 autobiography of benjamin franklin    NaN  B004UJNXVK
# 13181                 autobiography of benjamin franklin    NaN  B004UJNXVK
# 13182                                         test pilot   0.00  B004ZR9G5O
# 13183                                          one woman    NaN  B00AFE28DS
# 13184                                     altered states    NaN  B00550O1WI
# 13185                                             master   5.99  B00L8HO4Y2
# 13186                              barefoot in the grass    NaN  B004DNWSZA
# 13187                                 going nowhere fast    NaN  B00H240NGI
# 13188                                  high button shoes    NaN  B00CBJCQCI
# 13189                                 valentine surprise   2.80  B006YCEO1Y
# 13190                                       this is love    NaN  B00EZ4KO3A
# 13191                                        gilded cage    NaN  B007JLNIES
# 13192                                   deceptive nights    NaN  B0051ORV7K
# 13193                                            brianna   8.99  B005LJEUWO
# 13194             the little rabbit who wanted red wings   5.58  B00JSCK68W
# 13195             the little rabbit who wanted red wings    NaN  B00JSCK68W
# 13196                                     book of mormon  12.80  B00BNGXNW2
# 13197                                     never give up!  14.00  B00DJY04UU
# 13198                                             lilacs    NaN  B00C5UYGY4
# 13199                                        crawl space    NaN  B00BEBWBPQ
# 13200                              it's all in your mind    NaN  B00ED1ZFVG
# 13201                              the bath tatting book   8.99  B0083ZYV54
# 13202                                    beyond the door   1.99  B004UJORLK
# 13203                                      stormy affair    NaN  B0085BCFXG
# 13204  teachings of presidents of the church: george ...    NaN  B008DL5HB0
# 13205                                      wife for hire   1.99  B00BFQEFYU
# 13206                         pennsylvania dutch cooking    NaN  B004SQX4G4
# 13207                                        by the book    NaN  B003MAK5CI
#
#                                                authors  \
# 0                                        Joseph Porter
# 1                                        Joseph Porter
# 2                                        Joseph Porter
# 3                                        Joseph Porter
# 4                                        Joseph Porter
# 5                                        Joseph Porter
# 6                                        Joseph Porter
# 7                                        Joseph Porter
# 8                                         Willow Cross
# 9                                         Willow Cross
# 10                                        Willow Cross
# 11                                        Willow Cross
# 12                                        Willow Cross
# 13                                        Willow Cross
# 14                                        Willow Cross
# 15                                        Willow Cross
# 16                                        Willow Cross
# 17                                        Willow Cross
# 18                                        Willow Cross
# 19                                        Willow Cross
# 20                                        Willow Cross
# 21                                        Willow Cross
# 22                                        Willow Cross
# 23                                        Erik Tomblin
# 24                                        Erik Tomblin
# 25                                        Erik Tomblin
# 26                                        Erik Tomblin
# 27                                        Erik Tomblin
# 28                                        Erik Tomblin
# 29                                        Erik Tomblin
# ...                                                ...
# 13178                                    Mandy M. Roth
# 13179                                    Patti Roberts
# 13180                                Benjamin Franklin
# 13181                                Benjamin Franklin
# 13182                                  John H. Carroll
# 13183                              Eva Marie Paulliere
# 13184                                   Paul J. Newell
# 13185                                      Julia Sykes
# 13186                                    Judith Arnold
# 13187                                  K.D. Bloodworth
# 13188                                Margaret Brownley
# 13189                                  Jennifer Conner
# 13190                  Remmy Duchene, Allison Cassatta
# 13191                               Alexandra Richland
# 13192                                   Sylvia Hubbard
# 13193                                          Lexie X
# 13194                                      Sophy Hunte
# 13195                                      Sophy Hunte
# 13196  The Church of Jesus Christ of Latter-day Saints
# 13197                                  Avram E. Cosmin
# 13198                                       Megan Derr
# 13199                                           F. Poj
# 13200                                      Ann Herrick
# 13201                                            P. P.
# 13202                                   Philip K. Dick
# 13203                                      Netty Ejike
# 13204  The Church of Jesus Christ of Latter-day Saints
# 13205                                   Christine Bell
# 13206                                          Unknown
# 13207                                     JoAnn Carter
#
#                                           manufacturer
# 0                                       Talent Writers
# 1                                       Talent Writers
# 2                                       Talent Writers
# 3                                       Talent Writers
# 4                                       Talent Writers
# 5                                       Talent Writers
# 6                                       Talent Writers
# 7                                       Talent Writers
# 8                                         Willow Cross
# 9                                         Willow Cross
# 10                                        Willow Cross
# 11                                        Willow Cross
# 12                                        Willow Cross
# 13                                        Willow Cross
# 14                                        Willow Cross
# 15                                        Willow Cross
# 16                                        Willow Cross
# 17                                        Willow Cross
# 18                                        Willow Cross
# 19                                        Willow Cross
# 20                                        Willow Cross
# 21                                        Willow Cross
# 22                                        Willow Cross
# 23                                    Blue Fairy Books
# 24                                    Blue Fairy Books
# 25                                    Blue Fairy Books
# 26                                    Blue Fairy Books
# 27                                    Blue Fairy Books
# 28                                    Blue Fairy Books
# 29                                    Blue Fairy Books
# ...                                                ...
# 13178                                  The Raven Books
# 13179                                    Patti Roberts
# 13180                                              NaN
# 13181                                              NaN
# 13182                                  John H. Carroll
# 13183              Electromagnetic Publishing Services
# 13184                           Appian Publishing Ltd.
# 13185                                              NaN
# 13186                                    Judith Arnold
# 13187                       Planettopia Publishing LLC
# 13188                                Ten Talents Press
# 13189                                  Books to Go Now
# 13190                               Dreamspinner Press
# 13191                                              NaN
# 13192                        HubBooks Literary Service
# 13193                       Lesbian Romance Publishing
# 13194                                              NaN
# 13195                                              NaN
# 13196  The Church of Jesus Christ of Latter-day Saints
# 13197                                              NaN
# 13198                            Less Than Three Press
# 13199                                              NaN
# 13200                               Books We Love Ltd.
# 13201                                              NaN
# 13202                                              NaN
# 13203                              DeRafelo Publishing
# 13204  The Church of Jesus Christ of Latter-day Saints
# 13205                            Entangled: Indulgence
# 13206                                              NaN
# 13207                            White Rose Publishing
#
# [13208 rows x 9 columns]

# %% [markdown]
# -- --
# ## Review analysis

# %% [markdown]
# Even if we have some problems that will need to be fixed for the milestone 3, we have continued in the analysis. Of course we had to test with wrong data, but we will ensure that in the future, we will make it work on correct data (one with same author and title for books and ebooks). The code is here to show that we have worked on other steps of the pipeline.

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# /Users/MJ/anaconda/lib/python3.6/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %% [markdown]
# Here you will need to uncomment this and download vader_lexicon as described in the README.

# %%
#nltk.download_shell()

# %% [markdown]
# Next we are going to fetch the reviews of the books for which we have the ebooks.
#
# As the file for the reviews of the books is quite big, we are going the read it into chunks.

# %%
def find_matched(list_asins, in_path, out_path):
    pd.DataFrame(columns=[['asin','overall', 'summary', 'reviewerID', 'helpful','reviewText', 'reviewerName']]).to_csv(out_path)
    
    for chunk in pd.read_json(in_path, lines=True, chunksize=50000):
        
        # look if some asins of the chunk match the ones in the given list
        filtered = chunk[chunk['asin'].isin(list_asins)].dropna(how='all')
        
        if len(filtered) > 0:
            # write the data if any
            filtered[['asin','overall', 'summary', 'reviewerID', 'helpful','reviewText', 'reviewerName']].to_csv(out_path,header=False, mode='a')

# %%
if WRITE_FIND_MATCHED:
    find_matched(merged_metadatas['asin_book'].values, books_5core_path, matched_books_path)
    find_matched(merged_metadatas['asin_ebook'].values, kindle_5core_path, matched_ebooks_path)

# %% [markdown]
# Now that we have our reviews it is time to analyse their content. To compute the score of a book, we use two approaches:
#
# 1) A weighted average of the stars taking into account the helpfulness of the review as described below.
#
# Let $s_{i,j}$ be the $j$th rating of book $i$ and $n$ the number of ratings for this book. As other users can review a review by saying whether it is helpful, let $k_{i,j}$ be the number of the person who reviewed the review $s_{i,j}$ and let $u_{i,j}$ be the number of reviewer who found the review helpful among the $k_{i,j}$ reviewers. Then what we want to do is to give more weight to reviews which are helpful and less weight to reviews that the other users found useless. The maximum weight a review can have is 1 and the minimum is 0, then if a review has never been reviewed or it has been voted equally helpful and not helpful, its weight will be 0.5 which is neutral.
# $$w_{i,j}=\cases{\frac{u_{i,j}}{k_{i,j}}, \text{if } k_{i,j} \ne 0 \\0.5, \text{if } k_{i,j}=0}$$
#
#
# The weighted average is then:
#
# $$S_i = \frac{\sum_{j=1}^{n} w_{i,j}s_{i,j}}{\sum_{j=1}^{n} w_{i,j}}$$
#
# 2) A weighted average of the sentiment's intensity in the review taking into account the helpfulness with the weight being derived similarly as above.
#
# Here we are going to use the VADER (Valence Aware Dictionary sEntiment Reasoner) sentiment analyzer from the nltk package. VADER is based on lexicons of sentiment-related words and each words is rated as whether it is positive and negative, and how negative or positive it is. For example, the 'excellent' would be treated as more positive than 'good'.
#
# The score Vader returns is between -1 and 1, 1 for a very positive review, -1 for a very negative review, and 0 if it is neutral.
#
# Although Vader is not the most accurate tool and to analyse a piece of text it checks if any of the words in the text are present in the lexicon, therefore its accuracy depends on the coverage of the lexicons. It is the easiest approach we have for the moment as we cannot train a classifier since we don't have a proper training set.

# %%
sid = SentimentIntensityAnalyzer()

# %%
# compute the weight of a review
def weighted_helpful(x):
    # literal_eval will evaluate '[1 ,1]' as a list
    # we use literal_eval here since using astype(list) on the column was not working
    x = literal_eval(x)
    voters = int(x[0]) + int(x[1])
    return 0.5 if voters == 0 else int(x[0])/voters

# %%
# compute the weighted average of the two scores for a book
def weighted_scores(data):
    # get the weight
    data['weighted_help'] = (data['helpful'].astype(list)).apply(weighted_helpful)
    
    func = lambda x: sid.polarity_scores(x)['compound']
    
    data['sentiment_review'] = data['reviewText'].apply(func)
    data['sentiment_summary'] = data['summary'].apply(func)
    
    data['sentiment_average'] = (data['sentiment_review'] + data['sentiment_summary'])*0.5
    data['sentiment_rescaled'] = (data['sentiment_average'] + 1) * 2 + 1
    
    data['combined'] = (data['sentiment_rescaled'] + data['overall']) * 0.5
    
    # multiply the scores with the weight
    data['weighted_sentiment_review'] = data['weighted_help'] * data['sentiment_review']
    data['weighted_sentiment_summary'] = data['weighted_help'] * data['sentiment_summary']
    data['weighted_sentiment_average'] = data['weighted_help'] * data['sentiment_average']
    data['weighted_sentiment_rescaled'] = data['weighted_help'] * data['sentiment_rescaled']
    data['weighted_overall'] = data['weighted_help'] * data['overall']
    data['weighted_combined'] = data['weighted_help'] * data['combined']
    
    # sum everything
    weighted_score = data.groupby(data['asin']).sum()
    
    # divide by the sum of the weights to obtain the weighted average
    weighted_score['sentiment_review_score'] = weighted_score['weighted_sentiment_review']/weighted_score['weighted_help']
    weighted_score['sentiment_summary_score'] = weighted_score['weighted_sentiment_summary']/weighted_score['weighted_help']
    weighted_score['sentiment_average_score'] = weighted_score['weighted_sentiment_average']/weighted_score['weighted_help']
    weighted_score['sentiment_rescaled'] = weighted_score['weighted_sentiment_rescaled']/weighted_score['weighted_help']
    weighted_score['overall_score'] = weighted_score['weighted_overall']/weighted_score['weighted_help']
    weighted_score['combined_score'] = weighted_score['weighted_combined']/weighted_score['weighted_help']
    
    return weighted_score[['sentiment_review_score', 'sentiment_summary_score', 'sentiment_average_score', 'sentiment_rescaled', 'overall_score', 'combined_score']]

# %%
matched_ebooks= pd.read_csv(matched_ebooks_path)
matched_books = pd.read_csv(matched_books_path)

# %%
if WRITE_WEIGHTED_SCORE:
    weighted_scores_books = weighted_scores(matched_books.copy())
    weighted_scores_ebooks = weighted_scores(matched_ebooks.copy())

    weighted_scores_books.to_csv(weighted_scores_books_path)
    weighted_scores_ebooks.to_csv(weighted_scores_ebooks_path)

weighted_scores_books = pd.read_csv(weighted_scores_books_path)
weighted_scores_ebooks = pd.read_csv(weighted_scores_ebooks_path)

# %% [markdown]
# Once we have computed the different scores for the books and the ebooks, it is now time to combine those scores with our data.

# %%
merged_with_books = pd.merge(merged_metadatas, weighted_scores_books, left_on='asin_book', right_on='asin')
merged_with_all = pd.merge(merged_with_books, weighted_scores_ebooks, left_on='asin_ebook', right_on='asin', suffixes=['_book', '_ebook'])

# %%
merged_with_all[['title', 'combined_score_book', 'combined_score_ebook']].head()
# Out:
#                                                title  combined_score_book  \
# 0                                   the ice princess             3.599635
# 1                                 the sweetest taboo             3.931882
# 2  dragons from the sea (the strongbow saga, book 2)             4.250450
# 3                                               iced             4.246412
# 4                                      made in italy             4.486103
#
#    combined_score_ebook
# 0              4.257872
# 1              4.492361
# 2              4.272470
# 3              4.029660
# 4              4.065768

# %%
merged_with_all.shape[0]
# Out:
# 53

# %%
average_combined_score = merged_with_all[['combined_score_book', 'combined_score_ebook']].mean()
average_combined_score
# Out:
# combined_score_book     4.049749
# combined_score_ebook    4.108649
# dtype: float64

# %%
average_sentiment_score = merged_with_all[['sentiment_average_score_book', 'sentiment_average_score_ebook']].mean()
average_sentiment_score
# Out:
# sentiment_average_score_book     0.454737
# sentiment_average_score_ebook    0.462108
# dtype: float64

# %%
average_overall_score = merged_with_all[['overall_score_book', 'overall_score_ebook']].mean()
average_overall_score
# Out:
# overall_score_book     4.190025
# overall_score_ebook    4.293082
# dtype: float64

# %% [markdown]
# Here we are going to see if the sentiment's score is consistent with the ratings, meaning that reviewers giving high ratings should also be positive in their reviews.

# %%
reviews_books_with_sentiment = matched_books.copy()
f_sentiment = lambda x: sid.polarity_scores(x)['compound']
reviews_books_with_sentiment['sentiment_review'] = matched_books['reviewText'].apply(f_sentiment)
reviews_books_with_sentiment['sentiment_summary'] = matched_books['summary'].apply(f_sentiment)
reviews_books_with_sentiment['average'] = (reviews_books_with_sentiment['sentiment_review'] + reviews_books_with_sentiment['sentiment_summary'])*0.5

# %%
reviews_books_with_sentiment.groupby('overall').mean()
# Out:
#            Unnamed: 0  sentiment_review  sentiment_summary   average
# overall
# 1        3.683335e+06          0.212659          -0.160626  0.026016
# 2        3.191242e+06          0.258701          -0.034349  0.112176
# 3        3.451677e+06          0.467796           0.138467  0.303131
# 4        3.435581e+06          0.675070           0.279179  0.477124
# 5        3.741658e+06          0.728469           0.356776  0.542622

# %%
reviews_books_with_sentiment[reviews_books_with_sentiment['overall'] == 1].head()
# Out:
#      Unnamed: 0        asin  overall                             summary  \
# 11        23417  0007269854        1            Absurd police ineptitude
# 64        23470  0007269854        1                            Hated it
# 65        23471  0007269854        1                         Not so good
# 67        23473  0007269854        1            Audiobook CDs poor grade
# 100       23506  0007269854        1  I don't usually write bad reviews.
#
#          reviewerID   helpful  \
# 11   A38L3I3R3VRPTT    [0, 0]
# 64   A2T1ZGMIFSHWW2    [5, 5]
# 65   A23J25BQYRAIVX  [13, 15]
# 67   A3UYDNMNB7VX75    [0, 0]
# 100  A3RIGC6OUSKQ8R    [6, 6]
#
#                                             reviewText  \
# 11   I agree with the complaints about cliches, car...
# 64   Giving up at pg 139 (of 389, paperback). I no ...
# 65   If you're a fan of Scandinavian crime fiction,...
# 67   My complaint is not with the novel, but with t...
# 100  However, I am 78 pages into this book and I ma...
#
#                           reviewerName  sentiment_review  sentiment_summary  \
# 11   Bay Area Bibliophile "marisylvia"            0.6467             0.0000
# 64                     In Vino Veritas            0.8126            -0.6369
# 65                        Jack Tierney           -0.9862             0.4927
# 67          Jane F. Wiedel "dog lover"           -0.9821            -0.4767
# 100                     Mary Ann Moore           -0.7228             0.4310
#
#      average
# 11   0.32335
# 64   0.08785
# 65  -0.24675
# 67  -0.72940
# 100 -0.14590

# %%
reviews_books_with_sentiment.iloc[212]['reviewText']
# Out:
# "This book is just plain horrible and for me to say that is saying a lot.  I read everything and a Danielle Steel or Nora Roberts novel is like Shakespeare compared to this book.  I picked this book up because I loved Michael Chriton's Timeline so much.  I am facinated with the medieval ages and think the concept of someone from today's time comming in contact with the past is an intresting concept.  Unfortunately this book is not intresting in the least.  I went into the book really wanting to like it but the writing is so stiff and awkard.  The dialogue is not believable in the least.  The romance between Edward and Robyn which should be the focal point of the book is boring.  Edward is like a Ken doll, looks cute but is plastic with no personality.  I guess it doesn't matter in the end because he is not around for most of the story anyway.  If you read this book thinking you will learn something about the medieval ages you will be sorely dissappointed.  Edward doesn't talk like he's really from the medieval ages when he meets Robyn because it's a spell.  How convienent. The author didn't want to do in depth historical research so he uses spells to just explain everything away. I can't believe there are going to be two more books after this one.  If you want to read a wonderful book about the present meeting the medieval past get Timeline.  There is more action, romance, and historical accuracy in Time Line than you will ever find in Knight Errant."

# %% [markdown]
# This review above has a really positive sentiment score of 0.9735, but if we read the review, we can understand that it is quite the opposite. A second example is "Not so good" which yields a score of 0.4927, showing us the limitation of Vader.

# %% [markdown]
# We can observe here that the better the rating is, the more positive the text of the review is in average. The reviews with a rating of 1 are not negative in average. Even if the scores are not always accurate due to the limitation of Vader, they are consistent in average with the ratings.

# %%
reviews_ebooks_with_sentiment = matched_ebooks.copy()
reviews_ebooks_with_sentiment['sentiment_review'] = matched_ebooks['reviewText'].apply(f_sentiment)
reviews_ebooks_with_sentiment['sentiment_summary'] = matched_ebooks['summary'].apply(f_sentiment)
reviews_ebooks_with_sentiment['average'] = (reviews_ebooks_with_sentiment['sentiment_review'] + reviews_ebooks_with_sentiment['sentiment_summary'])*0.5

# %%
reviews_ebooks_with_sentiment.groupby('overall').mean()
# Out:
#            Unnamed: 0  sentiment_review  sentiment_summary   average
# overall
# 1        23266.285714         -0.150765          -0.153098 -0.151932
# 2        28643.590909          0.053472          -0.045726  0.003873
# 3        28790.469697          0.503538           0.186164  0.344851
# 4        29388.108069          0.663903           0.268574  0.466238
# 5        27860.713587          0.688401           0.355370  0.521885

# %% [markdown]
# The ratings seem to be consistent with the sentiment's score here again. Compared to books, the sentiment's score is slightly lower and even negative for a rating of 1.
#
# For the same rating, the books reviewer seems to be more positive in their review, this may be explained by the fact that books reviews tend to be longer and more descriptive than ebooks reviews.
#
# This analysis may not be really representative of the reality due to the limitation in size of our final dataset.

# %% [markdown]
# Sources:
# * *Improving the Amazon Review System by Exploiting the Credibility and Time-Decay of Public Reviews*, Bo-Chun Wang, Wen-Yuan Zhu, and Ling-Jyh Chen
# * Hutto, C.J. & Gilbert, E.E. (2014). *VADER: A Parsimonious Rule-based Model for Sentiment Analysis of Social Media Text. Eighth International Conference on Weblogs and Social Media (ICWSM-14)*. Ann Arbor, MI, June 2014.
